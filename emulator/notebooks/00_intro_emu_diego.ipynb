# %% [markdown]
# # 00_intro - Emulator Edition
#
# This notebook is a 1:1 port of `00_intro.ipynb` that runs against the
# Verilator emulator instead of a physical RFSoC. The acquisition cells now
# use the original `prog.acquire()` / `prog.acquire_decimated()` calls, and
# those methods automatically select hardware vs emulator behavior from the
# `soc` object type.
#
# ```
# soc = QickEmu(str(CFG_PATH))
# OUT = ARTIFACTS_ROOT / '<name>'
# soc = soc.make_soc(memdir=OUT)
# iq_list = prog.acquire_decimated(soc)   # or prog.acquire(...)
# ```
#
# **Skipped cells:**
# - DDR4 buffer cells (`24, 25, 26`) - the TB does not instantiate the DDR4
#   buffer IP.
# - "Ways to run programs" + scratchwork section (`58+`) - covered by the
#   build helpers above.

# %% [markdown]
# ## Setup

# %%
import sys
import importlib
import pathlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# path setup
REPO_ROOT  = pathlib.Path.cwd().parent          # emulator/
sys.path.insert(0,str(REPO_ROOT / '..' / 'qick_lib/'))
print(sys.path)
source_dir = REPO_ROOT / 'software' / 'source'
if str(source_dir) not in sys.path:
    sys.path.insert(0, str(source_dir))


import qick_emu
importlib.reload(qick_emu)          # pick up edits without kernel restart
from qick_emu import QickEmu

from qick.asm_v2 import AveragerProgramV2, QickSpan, QickSweep1D

# emulator init
# CFG_PATH = REPO_ROOT / 'notebooks' / 'qick_config_216.json'
CFG_PATH = REPO_ROOT / 'notebooks' / 'qick_emu_config.json'
soc      = QickEmu(str(CFG_PATH))
soccfg   = soc.soccfg

# artifact root
ARTIFACTS_ROOT = REPO_ROOT / 'artifacts' / '00_intro'
# ARTIFACTS_ROOT = REPO_ROOT / 'artifacts' / 'qick_emu_data'
ARTIFACTS_ROOT.mkdir(parents=True, exist_ok=True)

# Master switch — set False to skip Verilator runs and re-plot from existing CSVs
RUN_SIM = True

print(f'REPO_ROOT     : {REPO_ROOT}')
print(f'ARTIFACTS_ROOT: {ARTIFACTS_ROOT}')
print(soccfg)

# Default Path is the artifacts root.
OUT = ARTIFACTS_ROOT

## QICKEmu Auxiliary Functions
def QICKEmu_plot_dac(soc, OUT):
    # DAC waveform
    t_dac, dac = soc.load_dac(OUT)
    plt.figure(figsize=(10, 3))
    plt.plot(t_dac, dac, linewidth=0.8)
    plt.xlabel('time [us]'); plt.ylabel('DAC value'); plt.title('DAC output')
    plt.grid(True, ls=':'); plt.tight_layout(); plt.show()
# Out:
# QICK library version mismatch: 0.2.366 remote (the board), 0.2.388 local (the PC)
#                         This may cause errors, usually KeyError in QickConfig initialization.
#                         If this happens, you must bring your versions in sync.
# ['/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/../qick_lib', '/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/software/source', '/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/../qick_lib', '/usr/lib64/python39.zip', '/usr/lib64/python3.9', '/usr/lib64/python3.9/lib-dynload', '', '/home/dmartin2/venv/lib64/python3.9/site-packages', '/home/dmartin2/venv/lib/python3.9/site-packages']
# REPO_ROOT     : /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator
# ARTIFACTS_ROOT: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro
# QICK running on QICKEmu, software version 0.2.366
#
# Firmware configuration (built Sat Sep 28 22:15:40 2024):
#
# 	Global clocks (MHz): tProc dispatcher timing 430.080, RF reference 245.760
# 	Groups of related clocks: [tProc timing clock, DAC tile 1, DAC tile 2, DAC tile 3], [DAC tile 0], [ADC tile 2]
#
# 	2 signal generator channels:
# 	0:	axis_signal_gen_v6 - fs=9584.640 Msps, fabric=599.040 MHz
# 		envelope memory: 65536 complex samples (6.838 us)
# 		32-bit DDS, range=9584.640 MHz
# 		DAC tile 0, blk 0 is QICKEmu DAC port 0
# 	1:	axis_signal_gen_v6 - fs=9584.640 Msps, fabric=599.040 MHz
# 		envelope memory: 16384 complex samples (1.709 us)
# 		32-bit DDS, range=9584.640 MHz
# 		DAC tile 0, blk 1 is QICKEmu DAC port 1
#
# 	1 readout channels:
# 	0:	axis_dyn_readout_v1 - configured by tProc output 4
# 		fs=2457.600 Msps, decimated=307.200 MHz, 32-bit DDS, range=2457.600 MHz
# 		axis_avg_buffer v1.0 (no edge counter, no weights)
# 		memory 8192 accumulated, 4096 decimated (13.333 us)
# 		triggered by tport 10, pin 0, feedback to tProc input 0
# 		ADC tile 2, blk 0 is QICKEmu ADC port 0
#
# 	8 digital output pins:
# 	0:	PMOD0_0_LS
# 	1:	PMOD0_1_LS
# 	2:	PMOD0_2_LS
# 	3:	PMOD0_3_LS
# 	4:	PMOD0_4_LS
# 	5:	PMOD0_5_LS
# 	6:	PMOD0_6_LS
# 	7:	PMOD0_7_LS
#
# 	tProc: qick_processor ("v2") rev 21, core execution clock 200.000 MHz
# 		memories (words): program 4096, data 16384, waveform 1024
# 		external start pin: PMOD1_0_LS
# 		external stop pin: PMOD1_1_LS
#
# 	DDR4 memory buffer: 1073741824 samples (3.495 sec), 128 samples/transfer
# 		wired to readouts [0]
#
# 	MR buffer: 8192 samples (3.333 us), wired to readouts [0]

# %%
# QICKEmu channel assignments
GEN_CH    = 0
RO_CH     = 0
TRIG_TIME = 0.40   # us
FREQ      = 500    # MHz
FREQ      = 100    # MHz
# FREQ      = 10    # MHz
# FREQ      = 0    # MHz

# %% [markdown]
# ## Basic multi-pulse program
#
# Port of `00_intro.ipynb` cell 10. Five pulses of different styles back-to-back
# through a single RO window.

# %%
class MultiPulseProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch  = cfg['ro_ch']
        gen_ch = cfg['gen_ch']

        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        ramp_len = 0.2
        self.add_gauss(ch=gen_ch, name='ramp',
                       sigma=ramp_len/10, length=ramp_len, even_length=True)

        self.add_pulse(ch=gen_ch, name='myflattop', ro_ch=ro_ch,
                       style='flat_top', envelope='ramp',
                       freq=cfg['freq'], length=0.1, phase=0, gain=1.0)

        self.add_pulse(ch=gen_ch, name='mygaus', ro_ch=ro_ch,
                       style='arb', envelope='ramp',
                       freq=cfg['freq'], phase=0, gain=1.0)

        self.add_pulse(ch=gen_ch, name='myconst', ro_ch=ro_ch,
                       style='const', length=0.2,
                       freq=cfg['freq'], phase=0, gain=1.0)

        self.add_pulse(ch=gen_ch, name='myflattop2', ro_ch=ro_ch,
                       style='flat_top', envelope='ramp',
                       freq=cfg['freq'], length=0.1, phase=90, gain=1.0)

        self.add_readoutconfig(ch=ro_ch, name='myro', freq=cfg['freq'], gen_ch=gen_ch)
        self.send_readoutconfig(ch=ro_ch, name='myro', t=0)

    def _body(self, cfg):
        # NB: `ddr4=True` is a no-op in the emulator — kept so the program
        # matches the on-hardware version byte-for-byte.
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'], ddr4=True)
        self.pulse(ch=cfg['gen_ch'], name='myflattop',  t=0)
        self.pulse(ch=cfg['gen_ch'], name='mygaus',     t=0.4)
        self.pulse(ch=cfg['gen_ch'], name='myconst',    t=0.8)
        self.pulse(ch=cfg['gen_ch'], name='myflattop2', t=1.2)
        self.pulse(ch=cfg['gen_ch'], name='mygaus',     t=1.6)


config = {
    'gen_ch':    GEN_CH,
    'ro_ch':     RO_CH,
    'freq':      FREQ,
    'trig_time': TRIG_TIME,
    'ro_len':    1.9,
}

prog = MultiPulseProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

# %% [markdown]
# ### Simulate & plot (MultiPulse)

# %%
# emulator artifacts
OUT = ARTIFACTS_ROOT / 'multi_pulse'
OUT.mkdir(parents=True, exist_ok=True)

soc = soc.make_soc(memdir=OUT)
print(f'Artifacts -> {OUT}')

# Original API call; emulator/hardware dispatch is handled inside acquire_decimated.
iq_list = prog.acquire_decimated(soc, rounds=10)
t = prog.get_time_axis(ro_index=0)

## Plot DAC waveform
QICKEmu_plot_dac(soc, OUT)

plt.plot(t, iq_list[0][:,0], label="I value")
plt.plot(t, iq_list[0][:,1], label="Q value")
plt.plot(t, np.abs(iq_list[0].dot([1,1j])), label="magnitude")
plt.legend()
plt.ylabel("a.u.")
plt.xlabel("us");
# Out:
# Artifacts -> /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 13 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 13 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21985600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22135600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22285600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22435600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22585600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22735600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22885600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23035600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23175500.000 - Start tProc execution ###
# ### 24175500.000 - End tProc execution ###
# ### 24175500.000 - Reading avg/dec buffers ###
# ### 76475500.000 - Closing CSV files ###
# *** 76475500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.995 s; speed 25.637 us/s
# - Verilator: cpu 2.983 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 98 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 98 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22065600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22215600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22365600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22515600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22665600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22815600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22965600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23115600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23255500.000 - Start tProc execution ###
# ### 24255500.000 - End tProc execution ###
# ### 24255500.000 - Reading avg/dec buffers ###
# ### 76555500.000 - Closing CSV files ###
# *** 76555500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 2.980 s; speed 25.737 us/s
# - Verilator: cpu 2.975 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.030); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 76 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 76 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22045600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22195600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22345600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22495600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22645600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22795600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22945600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23095600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23235500.000 - Start tProc execution ###
# ### 24235500.000 - End tProc execution ###
# ### 24235500.000 - Reading avg/dec buffers ###
# ### 76535500.000 - Closing CSV files ###
# *** 76535500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 3.034 s; speed 25.271 us/s
# - Verilator: cpu 3.029 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 36 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 36 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22005600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22155600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22305600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22455600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22605600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22755600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22905600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23055600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23195500.000 - Start tProc execution ###
# ### 24195500.000 - End tProc execution ###
# ### 24195500.000 - Reading avg/dec buffers ###
# ### 76495500.000 - Closing CSV files ###
# *** 76495500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.962 s; speed 25.869 us/s
# - Verilator: cpu 2.957 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 5 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 5 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21975600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22125600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22275600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22425600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22575600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22725600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22875600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23025600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23165500.000 - Start tProc execution ###
# ### 24165500.000 - End tProc execution ###
# ### 24165500.000 - Reading avg/dec buffers ###
# ### 76465500.000 - Closing CSV files ###
# *** 76465500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.998 s; speed 25.575 us/s
# - Verilator: cpu 2.990 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 20 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 20 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21995600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22145600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22295600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22445600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22595600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22745600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22895600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23045600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23185500.000 - Start tProc execution ###
# ### 24185500.000 - End tProc execution ###
# ### 24185500.000 - Reading avg/dec buffers ###
# ### 76485500.000 - Closing CSV files ###
# *** 76485500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 3.015 s; speed 25.420 us/s
# - Verilator: cpu 3.009 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.030); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 85 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 85 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22055600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22205600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22355600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22505600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22655600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22805600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22955600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23105600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23245500.000 - Start tProc execution ###
# ### 24245500.000 - End tProc execution ###
# ### 24245500.000 - Reading avg/dec buffers ###
# ### 76545500.000 - Closing CSV files ###
# *** 76545500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 3.038 s; speed 25.241 us/s
# - Verilator: cpu 3.033 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 86 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 86 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22055600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22205600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22355600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22505600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22655600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22805600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22955600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23105600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23245500.000 - Start tProc execution ###
# ### 24245500.000 - End tProc execution ###
# ### 24245500.000 - Reading avg/dec buffers ###
# ### 76545500.000 - Closing CSV files ###
# *** 76545500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 2.997 s; speed 25.587 us/s
# - Verilator: cpu 2.992 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.076 s (elab=0.000, cvt=0.000, bld=0.074); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 64 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 64 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22035600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22185600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22335600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22485600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22635600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22785600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22935600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23085600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23225500.000 - Start tProc execution ###
# ### 24225500.000 - End tProc execution ###
# ### 24225500.000 - Reading avg/dec buffers ###
# ### 76525500.000 - Closing CSV files ###
# *** 76525500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 2.987 s; speed 25.668 us/s
# - Verilator: cpu 2.981 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.034 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.003 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 70 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 584 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/multi_pulse/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 70 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22045600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22195600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000248 ###
# ### 22345600.000 - Routing AXI write: addr=0x00060008 data=0x00000248 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22495600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000248 ###
# ### 22645600.000 - Routing AXI write: addr=0x00060020 data=0x00000248 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22795600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22945600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23095600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23235500.000 - Start tProc execution ###
# ### 24235500.000 - End tProc execution ###
# ### 24235500.000 - Reading avg/dec buffers ###
# ### 76535500.000 - Closing CSV files ###
# *** 76535500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 2.997 s; speed 25.581 us/s
# - Verilator: cpu 2.992 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %%
# print the program (ugly!)
print(prog)
# Out:
# macros:
# 	WriteReg(dst='s_core_w1', src=0)
# 	ConfigReadout(ch=0, name='myro', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a13130>}, t_regs={'t': 0})
# 	Delay(t=1.0, auto=True, gens=True, ros=True, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a13e50>}, t_regs={'t': 430})
# 	OpenLoop(n=1, name='reps')
# 	Trigger(ros=[0], tts=[], pins=[0], t=0.4, width=0.023251488095238096, ddr4=True, mr=False, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a130a0>, 'width': <qick.asm_v2.QickParam object at 0x7f4430a13fa0>}, t_regs={'t': 172, 'width': 10}, outdict=defaultdict(<class 'int'>, {}), trigset={0, 9, 10})
# 	Pulse(ch=0, name='myflattop', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a6b4f0>}, t_regs={'t': 0})
# 	Pulse(ch=0, name='mygaus', t=0.4, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a6b190>}, t_regs={'t': 172})
# 	Pulse(ch=0, name='myconst', t=0.8, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a6b310>}, t_regs={'t': 344})
# 	Pulse(ch=0, name='myflattop2', t=1.2, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a6b0a0>}, t_regs={'t': 516})
# 	Pulse(ch=0, name='mygaus', t=1.6, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a6bf70>}, t_regs={'t': 688})
# 	Wait(t=0, auto=True, gens=False, ros=True, tag=None, no_warn=True, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a6bd90>}, t_regs={'t': 990})
# 	Delay(t=0.5, auto=True, gens=True, ros=True, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430a6bf40>}, t_regs={'t': 1205})
# 	IncReg(dst='s_core_w1', src=1)
# 	CloseLoop()
# 	End()
# registers:
# 	reps: QickRegisterV2(addr=0, init=None)
# pulses:
# 	myflattop: QickPulse(waveforms=[Waveform(name='myflattop_w0', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=2, steps={}), length=60, conf=8), Waveform(name='myflattop_w1', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=16383, spans={}, quantize=1, steps={}), length=QickRawParam(par='length', start=60, spans={}, quantize=1, steps={}), conf=9), Waveform(name='myflattop_w2', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=60, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=2, steps={}), length=60, conf=8)])
# 	mygaus: QickPulse(waveforms=[Waveform(name='mygaus_w0', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=1, steps={}), length=120, conf=8)])
# 	myconst: QickPulse(waveforms=[Waveform(name='myconst_w0', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=1, steps={}), length=QickRawParam(par='length', start=120, spans={}, quantize=1, steps={}), conf=9)])
# 	myflattop2: QickPulse(waveforms=[Waveform(name='myflattop2_w0', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=1073741824, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=2, steps={}), length=60, conf=8), Waveform(name='myflattop2_w1', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=1073741824, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=16383, spans={}, quantize=1, steps={}), length=QickRawParam(par='length', start=60, spans={}, quantize=1, steps={}), conf=9), Waveform(name='myflattop2_w2', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=1073741824, spans={}, quantize=1, steps={}), env=60, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=2, steps={}), length=60, conf=8)])
# 	myro: QickPulse(waveforms=[Waveform(name='myro_w0', freq=QickRawParam(par='freq', start=-174762666, spans={}, quantize=-39, steps={}), phase=0, env=0, gain=0, length=3, conf=264)])
# expanded ASM:
# 	     NOP
# 	     REG_WR s12 imm #0
# 	     WPORT_WR p4 wmem [&8] @0
# 	     TIME #430 inc_ref
# 	     REG_WR r0 imm #0
# 	reps:
# 	     TRIG p0 set @172
# 	     TRIG p9 set @172
# 	     TRIG p10 set @172
# 	     TRIG p0 clr @182
# 	     TRIG p9 clr @182
# 	     TRIG p10 clr @182
# 	     WPORT_WR p0 wmem [&0] @0
# 	     WPORT_WR p0 wmem [&1] @0
# 	     WPORT_WR p0 wmem [&2] @0
# 	     WPORT_WR p0 wmem [&3] @172
# 	     WPORT_WR p0 wmem [&4] @344
# 	     WPORT_WR p0 wmem [&5] @516
# 	     WPORT_WR p0 wmem [&6] @516
# 	     WPORT_WR p0 wmem [&7] @516
# 	     WPORT_WR p0 wmem [&3] @688
# 	     REG_WR s15 label SKIP
# 	     WAIT [s15] @990 time
# 	     TIME #1205 inc_ref
# 	     REG_WR s12 op -op(s12 + #1)
# 	     REG_WR s15 label reps
# 	     TEST -op(r0 - #0)
# 	     JUMP [s15] -if(NZ) -wr(r0 op) -op(r0 + #1)
# 	     REG_WR s15 label NEXT
# 	     JUMP [s15]

# %% [markdown]
# ## Basic sweep program
#
# Port of `00_intro.ipynb` cells 13–18.

# %%
class SimpleSweepProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch  = cfg['ro_ch']
        gen_ch = cfg['gen_ch']

        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        self.add_loop('myloop', cfg['steps'])

        self.add_gauss(ch=gen_ch, name='ramp',
                       sigma=cfg['ramp_len']/10, length=cfg['ramp_len'],
                       even_length=True)
        self.add_pulse(ch=gen_ch, name='mypulse', ro_ch=ro_ch,
                       style='flat_top', envelope='ramp',
                       freq=cfg['freq'], length=cfg['flat_len'],
                       phase=cfg['phase'], gain=cfg['gain'])

        self.add_readoutconfig(ch=ro_ch, name='myro', freq=cfg['freq'], gen_ch=gen_ch)
        self.send_readoutconfig(ch=ro_ch, name='myro', t=0)

    def _body(self, cfg):
        self.pulse(ch=cfg['gen_ch'], name='mypulse', t=0)
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'])

# %% [markdown]
# ### 5-point phase+gain sweep, plot decimated I

# %%
# Port of cell 14
config = {
    'steps':    5,
    'gen_ch':   GEN_CH,
    'ro_ch':    RO_CH,
    'freq':     FREQ,
    'trig_time': TRIG_TIME,
    'ro_len':   0.35,
    'flat_len': 0.05,
    'ramp_len': 0.2,
    'phase':    QickSweep1D('myloop', -360, 720),
    'gain':     QickSweep1D('myloop',  0.0,  1.0),
}

prog = SimpleSweepProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

OUT = ARTIFACTS_ROOT / 'simple_sweep'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT)

iq_list = prog.acquire_decimated(soc, rounds=10)
t = prog.get_time_axis(ro_index=0)

## Plot DAC waveform
QICKEmu_plot_dac(soc, OUT)

for ii, iq in enumerate(iq_list[0]):
    plt.plot(t, iq[:,0], label="I value, step %d"%(ii))
    # plt.plot(iq[:,1], label="Q value, step %d"%(ii))
    # plt.plot(np.abs(iq.dot([1,1j])), label="mag, step %d"%(ii))
plt.legend()
plt.ylabel("a.u.")
plt.xlabel("us");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 28 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 28 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21995600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22145600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22295600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22445600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22595600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22745600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22895600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23045600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23185500.000 - Start tProc execution ###
# ### 24185500.000 - End tProc execution ###
# ### 24185500.000 - Reading avg/dec buffers ###
# ### 76485500.000 - Closing CSV files ###
# *** 76485500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 3.000 s; speed 25.610 us/s
# - Verilator: cpu 2.987 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 60 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 60 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22035600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22185600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22335600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22485600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22635600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22785600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22935600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23085600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23225500.000 - Start tProc execution ###
# ### 24225500.000 - End tProc execution ###
# ### 24225500.000 - Reading avg/dec buffers ###
# ### 76525500.000 - Closing CSV files ###
# *** 76525500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 2.997 s; speed 25.572 us/s
# - Verilator: cpu 2.993 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 3 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 3 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21975600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22125600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22275600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22425600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22575600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22725600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22875600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23025600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23165500.000 - Start tProc execution ###
# ### 24165500.000 - End tProc execution ###
# ### 24165500.000 - Reading avg/dec buffers ###
# ### 76465500.000 - Closing CSV files ###
# *** 76465500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.973 s; speed 25.768 us/s
# - Verilator: cpu 2.968 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 79 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 79 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22045600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22195600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22345600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22495600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22645600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22795600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22945600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23095600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23235500.000 - Start tProc execution ###
# ### 24235500.000 - End tProc execution ###
# ### 24235500.000 - Reading avg/dec buffers ###
# ### 76535500.000 - Closing CSV files ###
# *** 76535500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 3.040 s; speed 25.221 us/s
# - Verilator: cpu 3.035 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 46 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 46 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22015600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22165600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22315600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22465600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22615600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22765600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22915600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23065600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23205500.000 - Start tProc execution ###
# ### 24205500.000 - End tProc execution ###
# ### 24205500.000 - Reading avg/dec buffers ###
# ### 76505500.000 - Closing CSV files ###
# *** 76505500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 2.992 s; speed 25.621 us/s
# - Verilator: cpu 2.986 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 29 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 29 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21995600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22145600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22295600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22445600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22595600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22745600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22895600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23045600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23185500.000 - Start tProc execution ###
# ### 24185500.000 - End tProc execution ###
# ### 24185500.000 - Reading avg/dec buffers ###
# ### 76485500.000 - Closing CSV files ###
# *** 76485500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.973 s; speed 25.802 us/s
# - Verilator: cpu 2.964 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 1 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 1 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21975600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22125600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22275600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22425600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22575600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22725600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22875600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23025600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23165500.000 - Start tProc execution ###
# ### 24165500.000 - End tProc execution ###
# ### 24165500.000 - Reading avg/dec buffers ###
# ### 76465500.000 - Closing CSV files ###
# *** 76465500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.980 s; speed 25.702 us/s
# - Verilator: cpu 2.975 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.032 s (elab=0.000, cvt=0.000, bld=0.030); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 33 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 33 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22005600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22155600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22305600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22455600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22605600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22755600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22905600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23055600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23195500.000 - Start tProc execution ###
# ### 24195500.000 - End tProc execution ###
# ### 24195500.000 - Reading avg/dec buffers ###
# ### 76495500.000 - Closing CSV files ###
# *** 76495500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.972 s; speed 25.815 us/s
# - Verilator: cpu 2.963 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.032 s (elab=0.000, cvt=0.000, bld=0.030); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 73 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 73 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22045600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22195600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22345600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22495600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22645600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22795600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22945600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23095600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23235500.000 - Start tProc execution ###
# ### 24235500.000 - End tProc execution ###
# ### 24235500.000 - Reading avg/dec buffers ###
# ### 76535500.000 - Closing CSV files ###
# *** 76535500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 3.000 s; speed 25.575 us/s
# - Verilator: cpu 2.993 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 98 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 98 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22065600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22215600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22365600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22515600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22665600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22815600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22965600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23115600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23255500.000 - Start tProc execution ###
# ### 24255500.000 - End tProc execution ###
# ### 24255500.000 - Reading avg/dec buffers ###
# ### 76555500.000 - Closing CSV files ###
# *** 76555500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 77us; walltime 3.022 s; speed 25.379 us/s
# - Verilator: cpu 3.017 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %%
# print the program
print(prog)
# Out:
# macros:
# 	WriteReg(dst='s_core_w1', src=0)
# 	ConfigReadout(ch=0, name='myro', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430adcf10>}, t_regs={'t': 0})
# 	Delay(t=1.0, auto=True, gens=True, ros=True, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430adc430>}, t_regs={'t': 430})
# 	OpenLoop(n=1, name='reps')
# 	OpenLoop(n=5, name='myloop')
# 	Pulse(ch=0, name='mypulse', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44309901f0>}, t_regs={'t': 0})
# 	Trigger(ros=[0], tts=[], pins=[0], t=0.4, width=0.023251488095238096, ddr4=False, mr=False, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f4430adc7c0>, 'width': <qick.asm_v2.QickParam object at 0x7f4430adc220>}, t_regs={'t': 172, 'width': 10}, outdict=defaultdict(<class 'int'>, {}), trigset={0, 10})
# 	Wait(t=0, auto=True, gens=False, ros=True, tag=None, no_warn=True, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44309907c0>}, t_regs={'t': 323})
# 	Delay(t=0.5, auto=True, gens=True, ros=True, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44309904f0>}, t_regs={'t': 538})
# 	IncReg(dst='s_core_w1', src=1)
# 	CloseLoop()
# 	CloseLoop()
# 	End()
# registers:
# 	reps: QickRegisterV2(addr=0, init=None)
# 	myloop: QickRegisterV2(addr=1, init=None)
# 	scratch: QickRegisterV2(addr=2, init=None)
# pulses:
# 	mypulse: QickPulse(waveforms=[Waveform(name='mypulse_w0', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=-4294967296, spans={'myloop': 12884901888}, quantize=1, steps={'myloop': {'step': 3221225472, 'span': 12884901888}}), env=0, gain=QickRawParam(par='gain', start=0, spans={'myloop': 32766}, quantize=2, steps={'myloop': {'step': 8190, 'span': 32760}}), length=60, conf=8), Waveform(name='mypulse_w1', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=-4294967296, spans={'myloop': 12884901888}, quantize=1, steps={'myloop': {'step': 3221225472, 'span': 12884901888}}), env=0, gain=QickRawParam(par='gain', start=0, spans={'myloop': 16383}, quantize=1, steps={'myloop': {'step': 4095, 'span': 16380}}), length=QickRawParam(par='length', start=30, spans={}, quantize=1, steps={}), conf=9), Waveform(name='mypulse_w2', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=-4294967296, spans={'myloop': 12884901888}, quantize=1, steps={'myloop': {'step': 3221225472, 'span': 12884901888}}), env=60, gain=QickRawParam(par='gain', start=0, spans={'myloop': 32766}, quantize=2, steps={'myloop': {'step': 8190, 'span': 32760}}), length=60, conf=8)])
# 	myro: QickPulse(waveforms=[Waveform(name='myro_w0', freq=QickRawParam(par='freq', start=-174762666, spans={}, quantize=-39, steps={}), phase=0, env=0, gain=0, length=3, conf=264)])
# expanded ASM:
# 	     NOP
# 	     REG_WR s12 imm #0
# 	     WPORT_WR p4 wmem [&3] @0
# 	     TIME #430 inc_ref
# 	     REG_WR r0 imm #0
# 	reps:
# 	     REG_WR r1 imm #0
# 	myloop:
# 	     WPORT_WR p0 wmem [&0] @0
# 	     WPORT_WR p0 wmem [&1] @0
# 	     WPORT_WR p0 wmem [&2] @0
# 	     TRIG p0 set @172
# 	     TRIG p10 set @172
# 	     TRIG p0 clr @182
# 	     TRIG p10 clr @182
# 	     REG_WR s15 label SKIP
# 	     WAIT [s15] @323 time
# 	     TIME #538 inc_ref
# 	     REG_WR s12 op -op(s12 + #1)
# 	     REG_WR r_wave wmem [&0]
# 	     REG_WR r2 imm #-1073741824
# 	     REG_WR w1 op -op(w1 + r2)
# 	     REG_WR w3 op -op(w3 + #8190)
# 	     WMEM_WR &0
# 	     REG_WR r_wave wmem [&1]
# 	     REG_WR r2 imm #-1073741824
# 	     REG_WR w1 op -op(w1 + r2)
# 	     REG_WR w3 op -op(w3 + #4095)
# 	     WMEM_WR &1
# 	     REG_WR r_wave wmem [&2]
# 	     REG_WR r2 imm #-1073741824
# 	     REG_WR w1 op -op(w1 + r2)
# 	     REG_WR w3 op -op(w3 + #8190)
# 	     WMEM_WR &2
# 	     REG_WR s15 label myloop
# 	     TEST -op(r1 - #4)
# 	     JUMP [s15] -if(NZ) -wr(r1 op) -op(r1 + #1)
# 	     REG_WR r_wave wmem [&0]
# 	     REG_WR r2 imm #1073741824
# 	     REG_WR w1 op -op(w1 + r2)
# 	     REG_WR w3 op -op(w3 + #-40950)
# 	     WMEM_WR &0
# 	     REG_WR r_wave wmem [&1]
# 	     REG_WR r2 imm #1073741824
# 	     REG_WR w1 op -op(w1 + r2)
# 	     REG_WR w3 op -op(w3 + #-20475)
# 	     WMEM_WR &1
# 	     REG_WR r_wave wmem [&2]
# 	     REG_WR r2 imm #1073741824
# 	     REG_WR w1 op -op(w1 + r2)
# 	     REG_WR w3 op -op(w3 + #-40950)
# 	     WMEM_WR &2
# 	     REG_WR s15 label reps
# 	     TEST -op(r0 - #0)
# 	     JUMP [s15] -if(NZ) -wr(r0 op) -op(r0 + #1)
# 	     REG_WR s15 label NEXT
# 	     JUMP [s15]

# %% [markdown]
# ### Higher-res sweep with acquire() — I/Q loop

# %%
# Port of cell 16. `acquire()` in HW averages over reps × rounds; in the
# emulator the same call now runs the simulator automatically and loads the
# resulting CSV outputs.
config['steps'] = 201
prog = SimpleSweepProgram(soccfg, reps=1, final_delay=1.0, cfg=config)

OUT = ARTIFACTS_ROOT / 'simple_sweep_highres'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT, test_run_ns=500_000)

iq_list = prog.acquire(soc, rounds=1, progress=True)

## Plot DAC waveform
QICKEmu_plot_dac(soc, OUT)

# plt.plot(np.angle(iq_list[0][0].dot([1,1j]), deg=True))
plt.plot(iq_list[0][0,:,0], iq_list[0][0,:,1])
plt.ylabel("Q")
plt.xlabel("I");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_highres/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_highres ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_highres via plusarg ###
# ### TEST_RUN_TIME overridden to 500000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 24 ns ###
# ### RO_AVG_LEN overridden to 201 via plusarg ###
# ### RO_DEC_LEN overridden to 21708 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_highres/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_highres ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_highres/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 24 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21995600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22145600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22295600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22445600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22595600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22745600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22895600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23045600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23185500.000 - Start tProc execution ###
# ### 523185500.000 - End tProc execution ###
# ### 523185500.000 - Reading avg/dec buffers ###
# ### 575485500.000 - Closing CSV files ###
# *** 575485500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 575us; walltime 22.821 s; speed 25.271 us/s
# - Verilator: cpu 22.773 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %% [markdown]
# ### JSON dump / restore (cell 17)
#
# Pure-Python round-trip; no simulation required.

# %%
# Port of cell 17 — dump to JSON string and restore. The restored program is
# used as a structural sanity check; no emulator run.
from qick.asm_v2 import AcquireProgramV2
from qick.helpers import progs2json, json2progs

s = progs2json([prog.dump_prog()])
newprog = AcquireProgramV2(soccfg)
newprog.load_prog(json2progs(s)[0])
print('round-trip ok — restored program text ASM:')
print(newprog.asm()[:400])
print('...')
# Out:
# round-trip ok — restored program text ASM:
#      NOP
#      REG_WR s12 imm #0
#      WPORT_WR p4 wmem [&3] @0
#      TIME #430 inc_ref
#      REG_WR r0 imm #0
# reps:
#      REG_WR r1 imm #0
# myloop:
#      WPORT_WR p0 wmem [&0] @0
#      WPORT_WR p0 wmem [&1] @0
#      WPORT_WR p0 wmem [&2] @0
#      TRIG p0 set @172
#      TRIG p10 set @172
#      TRIG p0 clr @182
#      TRIG p10 clr @182
#      REG_WR s15 label SKIP
#      WAIT [s15] @323 time
#      TIME
# ...

# %% [markdown]
# ### Length sweep

# %%
# Port of cell 18 — sweep flat-top length and gain
config = {
    'steps':    5,
    'gen_ch':   GEN_CH,
    'ro_ch':    RO_CH,
    'freq':     FREQ,
    'trig_time': TRIG_TIME,
    'ro_len':   0.35,
    'flat_len': QickSweep1D('myloop', 0.05, 0.15),
    'ramp_len': 0.1,
    'phase':    0,
    'gain':     QickSweep1D('myloop', 0.5, 1.0),
}
prog = SimpleSweepProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

OUT = ARTIFACTS_ROOT / 'simple_sweep_length'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT)

iq_list = prog.acquire_decimated(soc, rounds=10)
t = prog.get_time_axis(ro_index=0)

plt.figure(1)
for ii, iq in enumerate(iq_list[0]):
    # plt.plot(t, iq[:,0], label="I value, step %d"%(ii))
    # plt.plot(t, iq[:,1], label="Q value, step %d"%(ii))
    plt.plot(t, np.abs(iq.dot([1,1j])), label="mag, step %d"%(ii))
plt.legend()
plt.ylabel("a.u.")
plt.xlabel("us");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 49 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 49 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12415600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12565600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12715600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12865600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 13015600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13165600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13315600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13465600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13605500.000 - Start tProc execution ###
# ### 14605500.000 - End tProc execution ###
# ### 14605500.000 - Reading avg/dec buffers ###
# ### 66905500.000 - Closing CSV files ###
# *** 66905500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.614 s; speed 25.647 us/s
# - Verilator: cpu 2.609 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 15 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 15 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12385600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12535600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12685600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12835600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 12985600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13135600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13285600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13435600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13575500.000 - Start tProc execution ###
# ### 14575500.000 - End tProc execution ###
# ### 14575500.000 - Reading avg/dec buffers ###
# ### 66875500.000 - Closing CSV files ###
# *** 66875500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.688 s; speed 24.964 us/s
# - Verilator: cpu 2.679 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.032 s (elab=0.000, cvt=0.000, bld=0.030); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 69 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 69 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12435600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12585600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12735600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12885600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 13035600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13185600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13335600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13485600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13625500.000 - Start tProc execution ###
# ### 14625500.000 - End tProc execution ###
# ### 14625500.000 - Reading avg/dec buffers ###
# ### 66925500.000 - Closing CSV files ###
# *** 66925500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.641 s; speed 25.382 us/s
# - Verilator: cpu 2.637 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 23 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 23 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12395600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12545600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12695600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12845600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 12995600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13145600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13295600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13445600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13585500.000 - Start tProc execution ###
# ### 14585500.000 - End tProc execution ###
# ### 14585500.000 - Reading avg/dec buffers ###
# ### 66885500.000 - Closing CSV files ###
# *** 66885500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.624 s; speed 25.537 us/s
# - Verilator: cpu 2.619 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 66 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 66 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12435600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12585600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12735600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12885600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 13035600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13185600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13335600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13485600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13625500.000 - Start tProc execution ###
# ### 14625500.000 - End tProc execution ###
# ### 14625500.000 - Reading avg/dec buffers ###
# ### 66925500.000 - Closing CSV files ###
# *** 66925500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.607 s; speed 25.719 us/s
# - Verilator: cpu 2.602 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 93 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 93 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12465600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12615600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12765600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12915600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 13065600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13215600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13365600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13515600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13655500.000 - Start tProc execution ###
# ### 14655500.000 - End tProc execution ###
# ### 14655500.000 - Reading avg/dec buffers ###
# ### 66955500.000 - Closing CSV files ###
# *** 66955500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.619 s; speed 25.619 us/s
# - Verilator: cpu 2.613 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 4 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 4 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12375600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12525600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12675600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12825600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 12975600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13125600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13275600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13425600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13565500.000 - Start tProc execution ###
# ### 14565500.000 - End tProc execution ###
# ### 14565500.000 - Reading avg/dec buffers ###
# ### 66865500.000 - Closing CSV files ###
# *** 66865500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.600 s; speed 25.777 us/s
# - Verilator: cpu 2.594 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 90 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 90 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12465600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12615600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12765600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12915600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 13065600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13215600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13365600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13515600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13655500.000 - Start tProc execution ###
# ### 14655500.000 - End tProc execution ###
# ### 14655500.000 - Reading avg/dec buffers ###
# ### 66955500.000 - Closing CSV files ###
# *** 66955500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.619 s; speed 25.611 us/s
# - Verilator: cpu 2.614 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 81 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 81 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12455600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12605600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12755600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12905600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 13055600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13205600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13355600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13505600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13645500.000 - Start tProc execution ###
# ### 14645500.000 - End tProc execution ###
# ### 14645500.000 - Reading avg/dec buffers ###
# ### 66945500.000 - Closing CSV files ###
# *** 66945500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.602 s; speed 25.770 us/s
# - Verilator: cpu 2.598 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 64 ns ###
# ### RO_AVG_LEN overridden to 5 via plusarg ###
# ### RO_DEC_LEN overridden to 540 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/simple_sweep_length/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 64 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12435600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12585600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 12735600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12885600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 13035600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13185600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13335600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13485600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13625500.000 - Start tProc execution ###
# ### 14625500.000 - End tProc execution ###
# ### 14625500.000 - Reading avg/dec buffers ###
# ### 66925500.000 - Closing CSV files ###
# *** 66925500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.649 s; speed 25.309 us/s
# - Verilator: cpu 2.644 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %% [markdown]
# ## Multi-dimensional loops and sweeps
#
# Port of `00_intro.ipynb` cells 20, 21, 22, 23. The DDR4 loop-order cells
# (24, 25, 26) are skipped — the TB has no DDR4 buffer.

# %%
# Port of cell 20
class Sweep2DProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch  = cfg['ro_ch']
        gen_ch = cfg['gen_ch']

        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        self.add_loop('loop1', cfg['steps1'])   # outer
        self.add_loop('loop2', cfg['steps2'])   # inner

        self.add_gauss(ch=gen_ch, name='ramp',
                       sigma=cfg['ramp_len']/10, length=cfg['ramp_len'],
                       even_length=True)
        self.add_pulse(ch=gen_ch, name='mypulse', ro_ch=ro_ch,
                       style='flat_top', envelope='ramp',
                       freq=cfg['freq'], length=cfg['flat_len'],
                       phase=cfg['phase'], gain=cfg['gain'])

        self.delay(0.5)                         # let tProc set up
        self.trigger(ddr4=True, mr=True, t=0)

        self.add_readoutconfig(ch=ro_ch, name='myro', freq=cfg['freq'], gen_ch=gen_ch)
        self.send_readoutconfig(ch=ro_ch, name='myro', t=0)

    def _body(self, cfg):
        self.pulse(ch=cfg['gen_ch'], name='mypulse', t=0)
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'])

# %% [markdown]
# ### Gain sweep on both loop levels (cell 21)

# %%
# Port of cell 21 — QickSpan summed across loops.
# HW version uses steps1=50, steps2=100; we shrink to keep the emulator run
# tractable but keep the same pattern.
config = {
    'steps1': 10,
    'steps2': 20,
    'gen_ch':   GEN_CH,
    'ro_ch':    RO_CH,
    'freq':     FREQ,
    'trig_time': TRIG_TIME,
    'ro_len':   0.35,
    'flat_len': 0.05,
    'ramp_len': 0.2,
    'phase':    0,
    'gain':     0.4 + QickSpan('loop1', 0.5) + QickSpan('loop2', 0.1),
}
prog = Sweep2DProgram(soccfg, reps=1, final_delay=1.0, cfg=config)

OUT = ARTIFACTS_ROOT / 'sweep_2d_gain'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT, test_run_ns=1_000_000)

iq_list = prog.acquire(soc, rounds=1, progress=True)

## Plot DAC waveform
QICKEmu_plot_dac(soc, OUT)


# plt.plot(np.angle(iq_list[0][0].dot([1,1j]), deg=True))
# plt.plot(iq_list[0][0,0,:,0], iq_list[0][0,0,:,1])
mag = np.abs(iq_list[0][0].dot([1,1j]))

fig, axes = plt.subplots(1,2, figsize=(12,6))
plot = axes[0]
plt.colorbar(plot.pcolormesh(mag/mag.max()))
plot.set_title("magnitude, actual")
plot.set_ylabel("step index, loop 1")
plot.set_xlabel("step index, loop 2");

plot = axes[1]
plt.colorbar(plot.pcolormesh(prog.get_pulse_param('mypulse', 'gain', as_array=True)))
plot.set_title("magnitude, expected")
plot.set_ylabel("step index, loop 1")
plot.set_xlabel("step index, loop 2");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain via plusarg ###
# ### TEST_RUN_TIME overridden to 1000000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 99 ns ###
# ### RO_AVG_LEN overridden to 200 via plusarg ###
# ### RO_DEC_LEN overridden to 21600 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 99 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22065600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22215600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22365600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22515600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22665600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22815600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22965600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23115600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23255500.000 - Start tProc execution ###
# ### 1023255500.000 - End tProc execution ###
# ### 1023255500.000 - Reading avg/dec buffers ###
# ### 1075555500.000 - Closing CSV files ###
# *** 1075555500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 1ms; walltime 41.707 s; speed 25.840 us/s
# - Verilator: cpu 41.623 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %%
# Port of cell 22 — two equivalent ways to query the swept gain grid
print(prog.get_pulse_param('mypulse', 'gain', as_array=True))
print(config['gain'].get_actual_values(prog.loop_dict))
# Out:
# [[0.39998779 0.40523714 0.41048648 0.41573582 0.42098517 0.42623451
#   0.43148386 0.4367332  0.44198254 0.44723189 0.45248123 0.45773057
#   0.46297992 0.46822926 0.47347861 0.47872795 0.48397729 0.48922664
#   0.49447598 0.49972533]
#  [0.45553317 0.46078252 0.46603186 0.47128121 0.47653055 0.48177989
#   0.48702924 0.49227858 0.49752793 0.50277727 0.50802661 0.51327596
#   0.5185253  0.52377464 0.52902399 0.53427333 0.53952268 0.54477202
#   0.55002136 0.55527071]
#  [0.51107856 0.5163279  0.52157724 0.52682659 0.53207593 0.53732528
#   0.54257462 0.54782396 0.55307331 0.55832265 0.563572   0.56882134
#   0.57407068 0.57932003 0.58456937 0.58981871 0.59506806 0.6003174
#   0.60556675 0.61081609]
#  [0.56662394 0.57187328 0.57712263 0.58237197 0.58762131 0.59287066
#   0.59812    0.60336935 0.60861869 0.61386803 0.61911738 0.62436672
#   0.62961607 0.63486541 0.64011475 0.6453641  0.65061344 0.65586278
#   0.66111213 0.66636147]
#  [0.62216932 0.62741867 0.63266801 0.63791735 0.6431667  0.64841604
#   0.65366538 0.65891473 0.66416407 0.66941342 0.67466276 0.6799121
#   0.68516145 0.69041079 0.69566014 0.70090948 0.70615882 0.71140817
#   0.71665751 0.72190685]
#  [0.6777147  0.68296405 0.68821339 0.69346274 0.69871208 0.70396142
#   0.70921077 0.71446011 0.71970945 0.7249588  0.73020814 0.73545749
#   0.74070683 0.74595617 0.75120552 0.75645486 0.76170421 0.76695355
#   0.77220289 0.77745224]
#  [0.73326009 0.73850943 0.74375877 0.74900812 0.75425746 0.75950681
#   0.76475615 0.77000549 0.77525484 0.78050418 0.78575352 0.79100287
#   0.79625221 0.80150156 0.8067509  0.81200024 0.81724959 0.82249893
#   0.82774828 0.83299762]
#  [0.78880547 0.79405481 0.79930416 0.8045535  0.80980284 0.81505219
#   0.82030153 0.82555088 0.83080022 0.83604956 0.84129891 0.84654825
#   0.8517976  0.85704694 0.86229628 0.86754563 0.87279497 0.87804431
#   0.88329366 0.888543  ]
#  [0.84435085 0.8496002  0.85484954 0.86009888 0.86534823 0.87059757
#   0.87584691 0.88109626 0.8863456  0.89159495 0.89684429 0.90209363
#   0.90734298 0.91259232 0.91784167 0.92309101 0.92834035 0.9335897
#   0.93883904 0.94408838]
#  [0.89989623 0.90514558 0.91039492 0.91564427 0.92089361 0.92614295
#   0.9313923  0.93664164 0.94189098 0.94714033 0.95238967 0.95763902
#   0.96288836 0.9681377  0.97338705 0.97863639 0.98388574 0.98913508
#   0.99438442 0.99963377]]
# [[[0.39998779 0.40523714 0.41048648 0.41573582 0.42098517 0.42623451
#    0.43148386 0.4367332  0.44198254 0.44723189 0.45248123 0.45773057
#    0.46297992 0.46822926 0.47347861 0.47872795 0.48397729 0.48922664
#    0.49447598 0.49972533]
#   [0.45553317 0.46078252 0.46603186 0.47128121 0.47653055 0.48177989
#    0.48702924 0.49227858 0.49752793 0.50277727 0.50802661 0.51327596
#    0.5185253  0.52377464 0.52902399 0.53427333 0.53952268 0.54477202
#    0.55002136 0.55527071]
#   [0.51107856 0.5163279  0.52157724 0.52682659 0.53207593 0.53732528
#    0.54257462 0.54782396 0.55307331 0.55832265 0.563572   0.56882134
#    0.57407068 0.57932003 0.58456937 0.58981871 0.59506806 0.6003174
#    0.60556675 0.61081609]
#   [0.56662394 0.57187328 0.57712263 0.58237197 0.58762131 0.59287066
#    0.59812    0.60336935 0.60861869 0.61386803 0.61911738 0.62436672
#    0.62961607 0.63486541 0.64011475 0.6453641  0.65061344 0.65586278
#    0.66111213 0.66636147]
#   [0.62216932 0.62741867 0.63266801 0.63791735 0.6431667  0.64841604
#    0.65366538 0.65891473 0.66416407 0.66941342 0.67466276 0.6799121
#    0.68516145 0.69041079 0.69566014 0.70090948 0.70615882 0.71140817
#    0.71665751 0.72190685]
#   [0.6777147  0.68296405 0.68821339 0.69346274 0.69871208 0.70396142
#    0.70921077 0.71446011 0.71970945 0.7249588  0.73020814 0.73545749
#    0.74070683 0.74595617 0.75120552 0.75645486 0.76170421 0.76695355
#    0.77220289 0.77745224]
#   [0.73326009 0.73850943 0.74375877 0.74900812 0.75425746 0.75950681
#    0.76475615 0.77000549 0.77525484 0.78050418 0.78575352 0.79100287
#    0.79625221 0.80150156 0.8067509  0.81200024 0.81724959 0.82249893
#    0.82774828 0.83299762]
#   [0.78880547 0.79405481 0.79930416 0.8045535  0.80980284 0.81505219
#    0.82030153 0.82555088 0.83080022 0.83604956 0.84129891 0.84654825
#    0.8517976  0.85704694 0.86229628 0.86754563 0.87279497 0.87804431
#    0.88329366 0.888543  ]
#   [0.84435085 0.8496002  0.85484954 0.86009888 0.86534823 0.87059757
#    0.87584691 0.88109626 0.8863456  0.89159495 0.89684429 0.90209363
#    0.90734298 0.91259232 0.91784167 0.92309101 0.92834035 0.9335897
#    0.93883904 0.94408838]
#   [0.89989623 0.90514558 0.91039492 0.91564427 0.92089361 0.92614295
#    0.9313923  0.93664164 0.94189098 0.94714033 0.95238967 0.95763902
#    0.96288836 0.9681377  0.97338705 0.97863639 0.98388574 0.98913508
#    0.99438442 0.99963377]]]

# %% [markdown]
# ### Gain × phase 2D sweep (cell 23)

# %%
# Port of cell 23. HW version was reps=100, steps1=50, steps2=100; we shrink
# for emulator-friendliness.
config = {
    'steps1':   10,
    'steps2':   20,
    'gen_ch':   GEN_CH,
    'ro_ch':    RO_CH,
    'freq':     FREQ,
    'trig_time': TRIG_TIME,
    'ro_len':   0.35,
    'flat_len': 0.05,
    'ramp_len': 0.2,
    'phase':    QickSweep1D('loop2', 0, 360),
    'gain':     QickSweep1D('loop1', 0.01, 1.0),
}
prog = Sweep2DProgram(soccfg, reps=1, final_delay=1.0, cfg=config)

OUT = ARTIFACTS_ROOT / 'sweep_2d_gain_phase'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT, test_run_ns=1_000_000)

iq_list = prog.acquire(soc, rounds=1, progress=True)

## Plot DAC waveform
QICKEmu_plot_dac(soc, OUT)

fig, axes = plt.subplots(2, 2, figsize=(12,12))

# get the exact values of the parameters, after rounding - this also works for scalars (without as_array), you will just get a float
phases = prog.get_pulse_param("mypulse", "phase", as_array=True)
gains = prog.get_pulse_param("mypulse", "gain", as_array=True)

plot = axes[0,0]
plt.colorbar(plot.pcolormesh(phases, gains, iq_list[0][0,:,:,0]), ax=plot)
plot.set_title("I")
plot.set_ylabel("gain")
plot.set_xlabel("phase")
plot = axes[0,1]
plt.colorbar(plot.pcolormesh(phases, gains, iq_list[0][0,:,:,1]), ax=plot)
plot.set_title("Q")
plot.set_ylabel("gain")
plot.set_xlabel("phase")

plot = axes[1,0]
plt.colorbar(plot.pcolormesh(phases, gains, np.abs(iq_list[0][0].dot([1,1j]))), ax=plot)
plot.set_title("magnitude")
plot.set_ylabel("gain")
plot.set_xlabel("phase")

plot = axes[1,1]
plt.colorbar(plot.pcolormesh(phases, gains, np.unwrap(np.angle(iq_list[0][0].dot([1,1j])), axis=1)), ax=plot)
plot.set_title("phase")
plot.set_ylabel("gain")
plot.set_xlabel("phase");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain_phase/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain_phase ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain_phase via plusarg ###
# ### TEST_RUN_TIME overridden to 1000000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 60 ns ###
# ### RO_AVG_LEN overridden to 200 via plusarg ###
# ### RO_DEC_LEN overridden to 21600 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain_phase/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain_phase ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/sweep_2d_gain_phase/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 60 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 22035600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22185600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22335600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22485600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22635600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22785600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22935600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23085600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23225500.000 - Start tProc execution ###
# ### 1023225500.000 - End tProc execution ###
# ### 1023225500.000 - Reading avg/dec buffers ###
# ### 1075525500.000 - Closing CSV files ###
# *** 1075525500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 1ms; walltime 41.631 s; speed 25.883 us/s
# - Verilator: cpu 41.553 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %% [markdown]
# _Cells 24–26 (DDR4 loop-order demo) skipped — TB has no DDR4 buffer IP._

# %% [markdown]
# ## MR buffer + FFT (cells 27–28)
#
# The MR (Multi-Rate) buffer is the full ADC-rate capture just after the
# readout's digital downconversion (pre-FIR / pre-decimation). The Verilator
# TB snapshots this bus into `mr_out.csv` when `+MR_LEN=<n>` is passed — we
# plumb that through `soc.run_verilator_tb(..., mr_len=N)`.
#
# On-hardware `soc.get_mr()` returns `(N, 2)` I/Q samples; `soc.load_mr(OUT)`
# does the same by reading the CSV.
#
# **Capture window:** the TB arms MR capture on the first rising edge of
# `axis_sg_dac_tvalid` (2-FF sync'd into ro_clk), i.e. the moment the DAC
# first drives a sample. Raw ADC samples then take several ro_clk cycles to
# propagate through the behavioral ADC → DDC → MR bus, so the first handful
# of rows contain pre-signal zeros — that's the transit time, not a bug.

# %%
# Port of cell 27. We drive the MR capture with a dedicated Sweep2D run that
# includes `trigger(ddr4=True, mr=True, t=0)` in the body — this is what
# `soc.config_mr_buf` + `soc.get_mr()` would fire on hardware.
config_mr = {
    'steps1':    4,
    'steps2':    5,
    'gen_ch':    GEN_CH,
    'ro_ch':     RO_CH,
    'freq':      500,
    'trig_time': TRIG_TIME,
    'ro_len':    0.35,
    'flat_len':  0.05,
    'ramp_len':  0.2,
    'phase':     QickSweep1D('loop2', 0, 180),
    'gain':      QickSweep1D('loop1', 0.5, 1.0),
}
prog_mr = Sweep2DProgram(soccfg, reps=1, final_delay=1.0, cfg=config_mr)

MR_ROWS = 256   # 8 samples per row → 2048 I/Q samples at fs_mr

OUT = ARTIFACTS_ROOT / 'mr_capture'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT)
prep    = soc.prepare(prog_mr, soc=soc, memdir=OUT)
soc.export_vivado_files(memdir=OUT)

if RUN_SIM:
    soc.run_verilator_tb(OUT, prog_mr, build=False, mr_len=MR_ROWS)

## Plot DAC waveform
QICKEmu_plot_dac(soc, OUT)

# Two time axes are available:
#  - t_mr (from soc.load_mr) is derived from ro_clk timestamps in the CSV and
#    matches actual sim time,
#  - prog.get_time_axis_mr(RO_CH, iq_mr) uses N/fs from soccfg, matching what
#    the on-hardware notebook does.
# Use the program-derived axis to stay API-compatible with 00_intro.ipynb.
_, iq_mr = soc.load_mr(OUT, time_unit='us')
t = prog_mr.get_time_axis_mr(RO_CH, iq_mr)

plt.figure(figsize=(10, 4))
plt.plot(t, iq_mr[:, 0], label='I')
plt.plot(t, iq_mr[:, 1], label='Q')
plt.xlabel('us'); plt.ylabel('a.u.')
plt.legend(); plt.grid(True, ls=':'); plt.tight_layout(); plt.show()
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/mr_capture/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/mr_capture ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/mr_capture via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 14 ns ###
# ### RO_AVG_LEN overridden to 20 via plusarg ###
# ### RO_DEC_LEN overridden to 2160 via plusarg ###
# ### MR_LEN overridden to 256 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/mr_capture/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/mr_capture ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/mr_capture/sgmem_ch0.mem ###
# ### 20965500.000 - SG ch0 envelope loaded ###
# ###         20965500.000 - Task sg_load_mem() end ###
# ### 21965500.000 - Applying pre-run startup delay of 14 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 21985600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 22135600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000006c ###
# ### 22285600.000 - Routing AXI write: addr=0x00060008 data=0x0000006c ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 22435600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000006c ###
# ### 22585600.000 - Routing AXI write: addr=0x00060020 data=0x0000006c ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 22735600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 22885600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 23035600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 23175500.000 - Start tProc execution ###
# ### 24175500.000 - End tProc execution ###
# ### 24175500.000 - Reading avg/dec buffers ###
# ### 76475500.000 - Closing CSV files ###
# *** 76475500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.990 s; speed 25.623 us/s
# - Verilator: cpu 2.985 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %%
# Port of cell 28 — plot the PSD of the MR buffer I+jQ samples.
# Note: we subtract the downconversion frequency in HW, so the image tone
# shows up at -2f.
from scipy.signal import welch
from numpy.fft import fftshift
fs_mr = soccfg['readouts'][RO_CH]['fs']   # MHz
fft_freqs, psd = fftshift(welch(iq_mr.dot([1,1j]), fs_mr, return_onesided=False, nperseg=128, detrend=False), axes=1)
plt.semilogy(fft_freqs, psd)
plt.xlabel("MHz")
# Out:
# Text(0.5, 0, 'MHz')

# %% [markdown]
# ## Timeline management (cells 30–35)

# %%
# Port of cell 30 — goofing around with timeline management
class DelayProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch  = cfg['ro_ch']
        gen_ch = cfg['gen_ch']

        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        self.add_loop('myloop', cfg['steps'])

        self.add_pulse(ch=gen_ch, name='mypulse', ro_ch=ro_ch,
                       style='const',
                       freq=cfg['freq'],
                       length=QickSweep1D('myloop', 0.05, 0.1),
                       phase=cfg['phase'], 
                       gain=cfg['gain'])

        self.add_readoutconfig(ch=ro_ch, name='myro', freq=cfg['freq'], gen_ch=gen_ch)
        self.send_readoutconfig(ch=ro_ch, name='myro', t=0)

    def _body(self, cfg):
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'], tag='trig')
        self.pulse(ch=cfg['gen_ch'], name='mypulse', t=0)
        self.delay(0.15, tag='delay1')
        self.pulse(ch=cfg['gen_ch'], name='mypulse', t=0)
        self.delay_auto(QickSweep1D('myloop', 0.15, 0.05), ros=False, tag='delay2')
        self.pulse(ch=cfg['gen_ch'], name='mypulse', t=0)
        self.pulse(ch=cfg['gen_ch'], name='mypulse',
                   t=QickSweep1D('myloop', 0.1, 0.15), tag='pulse4')


config = {  'steps':    3,
            'gen_ch':   GEN_CH,
            'ro_ch':    RO_CH,
            'freq':     FREQ,
            'trig_time': TRIG_TIME,
            'ro_len':   0.6,
            'phase':    0,
            'gain':     1.0
        }

prog = DelayProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

OUT = ARTIFACTS_ROOT / 'delay_timeline'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT)

iq_list = prog.acquire_decimated(soc, rounds=10)
t = prog.get_time_axis(ro_index=0)

## Plot DAC waveform
QICKEmu_plot_dac(soc, OUT)

for ii, iq in enumerate(iq_list[0]):
    # plt.plot(t, iq[:,0], label="I value, step %d"%(ii))
    # plt.plot(t, iq[:,1], label="Q value, step %d"%(ii))
    plt.plot(t, np.abs(iq.dot([1,1j])), label="mag, step %d"%(ii))
plt.legend()
plt.ylabel("a.u.")
plt.xlabel("us");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 94 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 94 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2365600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2515600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2665600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2815600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2965600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3115600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3265600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3415600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3555500.000 - Start tProc execution ###
# ### 4555500.000 - End tProc execution ###
# ### 4555500.000 - Reading avg/dec buffers ###
# ### 56855500.000 - Closing CSV files ###
# *** 56855500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.227 s; speed 25.575 us/s
# - Verilator: cpu 2.223 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 70 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 70 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2345600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2495600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2645600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2795600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2945600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3095600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3245600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3395600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3535500.000 - Start tProc execution ###
# ### 4535500.000 - End tProc execution ###
# ### 4535500.000 - Reading avg/dec buffers ###
# ### 56835500.000 - Closing CSV files ###
# *** 56835500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.226 s; speed 25.590 us/s
# - Verilator: cpu 2.221 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 0 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 0 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2275600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2425600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2575600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2725600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2875600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3025600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3175600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3325600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3465500.000 - Start tProc execution ###
# ### 4465500.000 - End tProc execution ###
# ### 4465500.000 - Reading avg/dec buffers ###
# ### 56765500.000 - Closing CSV files ###
# *** 56765500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.246 s; speed 25.324 us/s
# - Verilator: cpu 2.242 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 95 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 95 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2365600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2515600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2665600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2815600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2965600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3115600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3265600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3415600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3555500.000 - Start tProc execution ###
# ### 4555500.000 - End tProc execution ###
# ### 4555500.000 - Reading avg/dec buffers ###
# ### 56855500.000 - Closing CSV files ###
# *** 56855500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.226 s; speed 25.590 us/s
# - Verilator: cpu 2.222 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 91 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 91 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2365600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2515600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2665600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2815600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2965600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3115600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3265600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3415600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3555500.000 - Start tProc execution ###
# ### 4555500.000 - End tProc execution ###
# ### 4555500.000 - Reading avg/dec buffers ###
# ### 56855500.000 - Closing CSV files ###
# *** 56855500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.231 s; speed 25.523 us/s
# - Verilator: cpu 2.228 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 68 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 68 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2335600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2485600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2635600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2785600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2935600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3085600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3235600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3385600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3525500.000 - Start tProc execution ###
# ### 4525500.000 - End tProc execution ###
# ### 4525500.000 - Reading avg/dec buffers ###
# ### 56825500.000 - Closing CSV files ###
# *** 56825500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.266 s; speed 25.125 us/s
# - Verilator: cpu 2.262 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 69 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 69 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2335600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2485600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2635600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2785600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2935600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3085600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3235600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3385600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3525500.000 - Start tProc execution ###
# ### 4525500.000 - End tProc execution ###
# ### 4525500.000 - Reading avg/dec buffers ###
# ### 56825500.000 - Closing CSV files ###
# *** 56825500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.263 s; speed 25.159 us/s
# - Verilator: cpu 2.259 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 68 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 68 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2335600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2485600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2635600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2785600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2935600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3085600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3235600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3385600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3525500.000 - Start tProc execution ###
# ### 4525500.000 - End tProc execution ###
# ### 4525500.000 - Reading avg/dec buffers ###
# ### 56825500.000 - Closing CSV files ###
# *** 56825500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.231 s; speed 25.522 us/s
# - Verilator: cpu 2.227 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.034 s (elab=0.000, cvt=0.000, bld=0.032); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 74 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 74 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2345600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2495600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2645600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2795600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2945600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3095600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3245600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3395600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3535500.000 - Start tProc execution ###
# ### 4535500.000 - End tProc execution ###
# ### 4535500.000 - Reading avg/dec buffers ###
# ### 56835500.000 - Closing CSV files ###
# *** 56835500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.222 s; speed 25.622 us/s
# - Verilator: cpu 2.218 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 55 ns ###
# ### RO_AVG_LEN overridden to 3 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline ###
# ### VERIFY P_MEM[1] = 8c6000000000002b22 ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/delay_timeline/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 55 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2325600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2475600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x000000b8 ###
# ### 2625600.000 - Routing AXI write: addr=0x00060008 data=0x000000b8 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2775600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x000000b8 ###
# ### 2925600.000 - Routing AXI write: addr=0x00060020 data=0x000000b8 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3075600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3225600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3375600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3515500.000 - Start tProc execution ###
# ### 4515500.000 - End tProc execution ###
# ### 4515500.000 - Reading avg/dec buffers ###
# ### 56815500.000 - Closing CSV files ###
# *** 56815500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.267 s; speed 25.107 us/s
# - Verilator: cpu 2.263 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %%
print(prog)
# Out:
# macros:
# 	WriteReg(dst='s_core_w1', src=0)
# 	ConfigReadout(ch=0, name='myro', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f43eee72940>}, t_regs={'t': 0})
# 	Delay(t=1.0, auto=True, gens=True, ros=True, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f43eee72880>}, t_regs={'t': 430})
# 	OpenLoop(n=1, name='reps')
# 	OpenLoop(n=3, name='myloop')
# 	Trigger(ros=[0], tts=[], pins=[0], t=0.4, width=0.023251488095238096, ddr4=False, mr=False, tag='trig', t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec429400>, 'width': <qick.asm_v2.QickParam object at 0x7f43ec429f40>}, t_regs={'t': 172, 'width': 10}, outdict=defaultdict(<class 'int'>, {}), trigset={0, 10})
# 	Pulse(ch=0, name='mypulse', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec429d00>}, t_regs={'t': 0})
# 	Delay(t=0.15, auto=False, tag='delay1', t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec429ee0>}, t_regs={'t': 65})
# 	Pulse(ch=0, name='mypulse', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec429730>}, t_regs={'t': 0})
# 	Delay(t=<qick.asm_v2.QickParam object at 0x7f43eee72640>, auto=True, gens=True, ros=False, tag='delay2', t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec429c70>}, t_regs={'t': 'r2'})
# 	Pulse(ch=0, name='mypulse', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec4297f0>}, t_regs={'t': 0})
# 	Pulse(ch=0, name='mypulse', t=<qick.asm_v2.QickParam object at 0x7f43eee72190>, tag='pulse4', t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec429580>}, t_regs={'t': 'r3'})
# 	Wait(t=0, auto=True, gens=False, ros=True, tag=None, no_warn=True, t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec429fd0>}, t_regs={'t': 299})
# 	Delay(t=0.5, auto=True, gens=True, ros=True, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f43ec4296d0>}, t_regs={'t': 'r4'})
# 	IncReg(dst='s_core_w1', src=1)
# 	CloseLoop()
# 	CloseLoop()
# 	End()
# registers:
# 	reps: QickRegisterV2(addr=0, init=None)
# 	myloop: QickRegisterV2(addr=1, init=None)
# 	r2: QickRegisterV2(addr=2, init=QickRawParam(par='length', start=86, spans={'myloop': -21}, quantize=1, steps={'myloop': {'step': -10, 'span': -20}}))
# 	r3: QickRegisterV2(addr=3, init=QickRawParam(par='length', start=43, spans={'myloop': 22}, quantize=1, steps={'myloop': {'step': 11, 'span': 22}}))
# 	r4: QickRegisterV2(addr=4, init=QickRawParam(par='length', start=494, spans={'myloop': 20}, quantize=1, steps={'myloop': {'step': 10, 'span': 20}}))
# pulses:
# 	mypulse: QickPulse(waveforms=[Waveform(name='mypulse_w0', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=1, steps={}), length=QickRawParam(par='length', start=30, spans={'myloop': 30}, quantize=1, steps={'myloop': {'step': 15, 'span': 30}}), conf=9)])
# 	myro: QickPulse(waveforms=[Waveform(name='myro_w0', freq=QickRawParam(par='freq', start=-174762666, spans={}, quantize=-39, steps={}), phase=0, env=0, gain=0, length=3, conf=264)])
# expanded ASM:
# 	     NOP
# 	     REG_WR r2 imm #86
# 	     REG_WR r3 imm #43
# 	     REG_WR r4 imm #494
# 	     REG_WR s12 imm #0
# 	     WPORT_WR p4 wmem [&1] @0
# 	     TIME #430 inc_ref
# 	     REG_WR r0 imm #0
# 	reps:
# 	     REG_WR r1 imm #0
# 	myloop:
# 	     TRIG p0 set @172
# 	     TRIG p10 set @172
# 	     TRIG p0 clr @182
# 	     TRIG p10 clr @182
# 	     WPORT_WR p0 wmem [&0] @0
# 	     TIME #65 inc_ref
# 	     WPORT_WR p0 wmem [&0] @0
# 	     TIME inc_ref r2
# 	     WPORT_WR p0 wmem [&0] @0
# 	     REG_WR s14 op -op(r3)
# 	     WPORT_WR p0 wmem [&0]
# 	     REG_WR s15 label SKIP
# 	     WAIT [s15] @299 time
# 	     TIME inc_ref r4
# 	     REG_WR s12 op -op(s12 + #1)
# 	     REG_WR r_wave wmem [&0]
# 	     REG_WR w4 op -op(w4 + #15)
# 	     WMEM_WR &0
# 	     REG_WR r2 op -op(r2 + #-10)
# 	     REG_WR r3 op -op(r3 + #11)
# 	     REG_WR r4 op -op(r4 + #10)
# 	     REG_WR s15 label myloop
# 	     TEST -op(r1 - #2)
# 	     JUMP [s15] -if(NZ) -wr(r1 op) -op(r1 + #1)
# 	     REG_WR r_wave wmem [&0]
# 	     REG_WR w4 op -op(w4 + #-45)
# 	     WMEM_WR &0
# 	     REG_WR r2 op -op(r2 + #30)
# 	     REG_WR r3 op -op(r3 + #-33)
# 	     REG_WR r4 op -op(r4 + #-30)
# 	     REG_WR s15 label reps
# 	     TEST -op(r0 - #0)
# 	     JUMP [s15] -if(NZ) -wr(r0 op) -op(r0 + #1)
# 	     REG_WR s15 label NEXT
# 	     JUMP [s15]

# %% [markdown]
# ### Timeline introspection (cells 32–35)
#
# Pure Python — no simulation needed.

# %%
# Port of cell 32
prog.get_time_param('delay1', 't')
# Out:
# 0.15113467261904762

# %%
# Port of cell 33 — swept parameters come back as QickParam; use as_array
print(prog.get_time_param('delay2', 't', as_array=True))
print(prog.get_time_param('delay2', 't').to_array(prog.loop_dict))
# Out:
# [0.1999628  0.17671131 0.15345982]
# [0.1999628  0.17671131 0.15345982]

# %%
# Port of cell 34 — compute the end time of the third pulse
(prog.get_time_param('delay1', 't')
 + prog.get_time_param('delay2', 't')
 + prog.get_pulse_param('mypulse', 'total_length')).to_array(prog.loop_dict)
# Out:
# array([0.4011776 , 0.40296617, 0.40475475])

# %%
# Port of cell 35 — discover what pulse params exist
prog.list_pulse_params('mypulse')
# Out:
# ['length', 'gain', 'phase', 'freq', 'total_length']

# %% [markdown]
# ## Feedback (cells 39, 41, 42, 43)
#
# ### Tuning the readout latency
#
# Cell 39 measures the phase offset between the generated pulse and the
# received readout so the feedback threshold can be set correctly. On hardware
# the last two prints depend on `soc.read_mem(...)` which reads the tProc's
# data memory *after* a run — the emulator TB does not currently dump the
# post-run `dmem` back to the host, so those lines are commented out. The
# `phase_offset` value is still computed from the decimated I/Q so the
# downstream `FeedbackProgram` cells can use it.

# %%
# Port of cell 39 — ReadProgram
class ReadProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch  = cfg['ro_ch']
        gen_ch = cfg['gen_ch']

        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        self.add_pulse(ch=gen_ch, name='mypulse', ro_ch=ro_ch,
                       style='const',
                       freq=cfg['freq'], 
                       length=cfg['pulse_len'],
                       phase=cfg['pulse_phase'], 
                       gain=cfg['gain']
                       )

        self.add_readoutconfig(ch=ro_ch, name='myro',
                               freq=cfg['freq'], gen_ch=gen_ch,
                               phase=cfg['ro_phase'])
        self.send_readoutconfig(ch=ro_ch, name='myro', t=0)

    def _body(self, cfg):
        self.pulse(ch=cfg['gen_ch'], name='mypulse', t=0)
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'])
        self.wait_auto(cfg['read_wait'])
        self.read_input(ro_ch=cfg['ro_ch'])
        self.write_dmem(addr=0, src='s_port_l')
        self.write_dmem(addr=1, src='s_port_h')


config = {
    'gen_ch':      GEN_CH,
    'ro_ch':       RO_CH,
    'freq':        FREQ,
    'trig_time':   TRIG_TIME,
    'read_wait':   0.1,
    'ro_len':      0.1,
    'pulse_len':   0.025,
    'pulse_phase': 0,
    'ro_phase':    0,
    'gain':        1.0,
}

prog = ReadProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

OUT = ARTIFACTS_ROOT / 'read_program'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT)

iq_list = prog.acquire_decimated(soc, rounds=1)
t  = prog.get_time_axis(ro_index=0)

plt.plot(t, iq_list[0][:,0], label="I value")
plt.plot(t, iq_list[0][:,1], label="Q value")
plt.plot(t, np.abs(iq_list[0].dot([1,1j])), label="mag")
plt.legend()
plt.ylabel("a.u.")
plt.xlabel("us");

phase_offset = np.angle(iq_list[0].sum(axis=0).dot([1,1j]), deg=True)
print("phase offset:", phase_offset)

print("buffered readout:", iq_list[0].sum(axis=0))
# On-hardware would read back tProc dmem here:
#   print('feedback readout:', soc.read_mem(2, 'dmem'))
# Not implemented in the emulator TB yet.
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/read_program/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.030); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/read_program ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/read_program via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 24 ns ###
# ### RO_AVG_LEN overridden to 1 via plusarg ###
# ### RO_DEC_LEN overridden to 31 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/read_program/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/read_program ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/read_program/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 24 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2295600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2445600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2595600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2745600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2895600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3045600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3195600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3345600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3485500.000 - Start tProc execution ###
# ### 4485500.000 - End tProc execution ###
# ### 4485500.000 - Reading avg/dec buffers ###
# ### 56785500.000 - Closing CSV files ###
# *** 56785500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 57us; walltime 2.260 s; speed 25.247 us/s
# - Verilator: cpu 2.249 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# phase offset: 98.27737790551012
# buffered readout: [-4697. 32286.]

# %% [markdown]
# ### Using feedback

# %%
# Port of cell 41 — FeedbackProgram: threshold + conditional jump
class FeedbackProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch  = cfg['ro_ch']
        gen_ch = cfg['gen_ch']

        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        self.add_loop('myloop', cfg['steps'])

        self.add_pulse(ch=gen_ch, name='mypulse', ro_ch=ro_ch,
                       style='const',
                       freq=cfg['freq'], length=cfg['pulse_len'],
                       phase=cfg['pulse_phase'], gain=cfg['gain'])

        self.add_readoutconfig(ch=ro_ch, name='myro',
                               freq=cfg['freq'], gen_ch=gen_ch,
                               phase=cfg['ro_phase'])
        self.send_readoutconfig(ch=ro_ch, name='myro', t=0)

    def _body(self, cfg):
        # pulse + first readout
        self.pulse(ch=cfg['gen_ch'], name='mypulse', t=0)
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'])

        # wait for the first readout to finish, then a small safety delay
        self.wait_auto(cfg['read_wait'])
        self.delay_auto(cfg['read_wait'] + cfg['extra_delay'])

        # second readout
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'])

        # read & branch
        self.read_and_jump(ro_ch=cfg['ro_ch'], component='I',
                           threshold=cfg['threshold'], test='>=', label='NOPULSE')

        # this pulse is skipped when I >= threshold
        self.pulse(ch=cfg['gen_ch'], name='mypulse', t=0)
        self.label('NOPULSE')


config = {
    'steps':       9,
    'gen_ch':      GEN_CH,
    'ro_ch':       RO_CH,
    'freq':        FREQ,
    'trig_time':   TRIG_TIME,
    'read_wait':   0.1,
    'extra_delay': 0.2,
    'threshold':   0,
    'ro_len':      0.1,
    'pulse_len':   0.025,
    'pulse_phase': 0,
    'ro_phase':    -phase_offset,
    'gain':        QickSweep1D('myloop', -1.0, 1.0),
}

prog = FeedbackProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

OUT = ARTIFACTS_ROOT / 'feedback_9steps'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT, test_run_ns=20_000)

iq_list = prog.acquire_decimated(soc, rounds=10)

t = prog.get_time_axis(ro_index=0)

fig, axes = plt.subplots(1, 2, figsize=(12,5))
for iRead in range(2):
    plot = axes[iRead]
    for ii, iq in enumerate(iq_list[0]):
        plot.plot(t, iq[iRead,:,0], label="I value, step %d"%(ii))
        # plt.plot(iq[:,1], label="Q value, step %d"%(ii))
        # plt.plot(np.abs(iq.dot([1,1j])), label="mag, step %d"%(ii))
    
    plot.set_title("I value, readout %d"%(iRead+1))
    plot.set_ylabel("a.u.")
    plot.set_xlabel("us")
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 67 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 67 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2335600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2485600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2635600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2785600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2935600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3085600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3235600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3385600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3525500.000 - Start tProc execution ###
# ### 23525500.000 - End tProc execution ###
# ### 23525500.000 - Reading avg/dec buffers ###
# ### 75825500.000 - Closing CSV files ###
# *** 75825500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.952 s; speed 25.801 us/s
# - Verilator: cpu 2.939 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 22 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 22 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2295600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2445600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2595600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2745600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2895600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3045600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3195600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3345600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3485500.000 - Start tProc execution ###
# ### 23485500.000 - End tProc execution ###
# ### 23485500.000 - Reading avg/dec buffers ###
# ### 75785500.000 - Closing CSV files ###
# *** 75785500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.963 s; speed 25.624 us/s
# - Verilator: cpu 2.958 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 28 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 28 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2295600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2445600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2595600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2745600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2895600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3045600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3195600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3345600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3485500.000 - Start tProc execution ###
# ### 23485500.000 - End tProc execution ###
# ### 23485500.000 - Reading avg/dec buffers ###
# ### 75785500.000 - Closing CSV files ###
# *** 75785500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.941 s; speed 25.816 us/s
# - Verilator: cpu 2.936 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.036 s (elab=0.000, cvt=0.000, bld=0.034); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 98 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 98 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2365600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2515600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2665600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2815600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2965600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3115600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3265600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3415600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3555500.000 - Start tProc execution ###
# ### 23555500.000 - End tProc execution ###
# ### 23555500.000 - Reading avg/dec buffers ###
# ### 75855500.000 - Closing CSV files ###
# *** 75855500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.990 s; speed 25.419 us/s
# - Verilator: cpu 2.984 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 47 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 47 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2315600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2465600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2615600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2765600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2915600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3065600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3215600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3365600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3505500.000 - Start tProc execution ###
# ### 23505500.000 - End tProc execution ###
# ### 23505500.000 - Reading avg/dec buffers ###
# ### 75805500.000 - Closing CSV files ###
# *** 75805500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.950 s; speed 25.740 us/s
# - Verilator: cpu 2.945 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 81 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 81 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2355600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2505600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2655600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2805600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2955600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3105600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3255600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3405600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3545500.000 - Start tProc execution ###
# ### 23545500.000 - End tProc execution ###
# ### 23545500.000 - Reading avg/dec buffers ###
# ### 75845500.000 - Closing CSV files ###
# *** 75845500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.981 s; speed 25.506 us/s
# - Verilator: cpu 2.974 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 34 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 34 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2305600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2455600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2605600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2755600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2905600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3055600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3205600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3355600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3495500.000 - Start tProc execution ###
# ### 23495500.000 - End tProc execution ###
# ### 23495500.000 - Reading avg/dec buffers ###
# ### 75795500.000 - Closing CSV files ###
# *** 75795500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.969 s; speed 25.575 us/s
# - Verilator: cpu 2.964 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 50 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 50 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2325600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2475600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2625600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2775600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2925600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3075600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3225600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3375600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3515500.000 - Start tProc execution ###
# ### 23515500.000 - End tProc execution ###
# ### 23515500.000 - Reading avg/dec buffers ###
# ### 75815500.000 - Closing CSV files ###
# *** 75815500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 3.077 s; speed 24.695 us/s
# - Verilator: cpu 3.070 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 56 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 56 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2325600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2475600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2625600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2775600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2925600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3075600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3225600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3375600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3515500.000 - Start tProc execution ###
# ### 23515500.000 - End tProc execution ###
# ### 23515500.000 - Reading avg/dec buffers ###
# ### 75815500.000 - Closing CSV files ###
# *** 75815500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.985 s; speed 25.446 us/s
# - Verilator: cpu 2.979 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps via plusarg ###
# ### TEST_RUN_TIME overridden to 20000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 91 ns ###
# ### RO_AVG_LEN overridden to 18 via plusarg ###
# ### RO_DEC_LEN overridden to 558 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_9steps/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 91 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2365600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2515600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2665600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2815600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2965600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3115600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3265600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3415600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3555500.000 - Start tProc execution ###
# ### 23555500.000 - End tProc execution ###
# ### 23555500.000 - Reading avg/dec buffers ###
# ### 75855500.000 - Closing CSV files ###
# *** 75855500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 76us; walltime 2.944 s; speed 25.814 us/s
# - Verilator: cpu 2.939 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %%
# Port of cell 42 — 200-step gain sweep, first vs second readout
# HW ran reps=1 with acquire(); we do the same.
config['steps'] = 50   # shrunk from 200 for emulator runtime

prog = FeedbackProgram(soccfg, reps=1, final_delay=0.5, cfg=config)
gains = prog.get_pulse_param('mypulse', 'gain', as_array=True)

OUT = ARTIFACTS_ROOT / 'feedback_long'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT, test_run_ns=100_000)

iq_list = prog.acquire(soc, rounds=1)

ro_len = len(prog.get_time_axis(ro_index=0))

# multiply the acquired I values by the length of the readout window, to undo length-normalization and get the raw units used for feedback
i_vals = iq_list[0][:,:,0]*ro_len
plt.plot(i_vals[0],i_vals[1])

plt.ylabel("I, second readout")
plt.xlabel("I, first readout");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_long/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.034 s (elab=0.000, cvt=0.000, bld=0.032); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_long ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_long via plusarg ###
# ### TEST_RUN_TIME overridden to 100000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 92 ns ###
# ### RO_AVG_LEN overridden to 100 via plusarg ###
# ### RO_DEC_LEN overridden to 3100 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_long/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_long ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_long/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 92 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2365600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2515600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2665600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2815600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2965600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3115600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3265600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3415600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3555500.000 - Start tProc execution ###
# ### 103555500.000 - End tProc execution ###
# ### 103555500.000 - Reading avg/dec buffers ###
# ### 155855500.000 - Closing CSV files ###
# *** 155855500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 156us; walltime 6.154 s; speed 25.376 us/s
# - Verilator: cpu 6.142 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %%
# Port of cell 43 — thresholded readout (not actually feedback)
# In HW this uses `prog.acquire(soc, threshold=0, angle=0)`. The emulator now
# uses the same call and applies the threshold internally.
prog = FeedbackProgram(soccfg, reps=1, final_delay=0.5, cfg=config)

OUT = ARTIFACTS_ROOT / 'feedback_threshold'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT, test_run_ns=100_000)

iq_list = prog.acquire(soc, rounds=1, threshold=0, angle=0)

plt.plot(gains, iq_list[0][0,:,0], label="first readout")
plt.plot(gains, iq_list[0][1,:,0], label="second readout")
plt.legend()
plt.ylabel("fraction")
plt.xlabel("gain");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_threshold/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.034 s (elab=0.000, cvt=0.000, bld=0.032); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_threshold ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_threshold via plusarg ###
# ### TEST_RUN_TIME overridden to 100000 ns ###
# ### PRE_RUN_DELAY_NS overridden to 2 ns ###
# ### RO_AVG_LEN overridden to 100 via plusarg ###
# ### RO_DEC_LEN overridden to 3100 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_threshold/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_threshold ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - SG ch0: no envelope file /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/feedback_threshold/sgmem_ch0.mem ###
# ### 2265600.000 - Applying pre-run startup delay of 2 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 2275600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 2425600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x0000001f ###
# ### 2575600.000 - Routing AXI write: addr=0x00060008 data=0x0000001f ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 2725600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x0000001f ###
# ### 2875600.000 - Routing AXI write: addr=0x00060020 data=0x0000001f ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 3025600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 3175600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 3325600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 3465500.000 - Start tProc execution ###
# ### 103465500.000 - End tProc execution ###
# ### 103465500.000 - Reading avg/dec buffers ###
# ### 155765500.000 - Closing CSV files ###
# *** 155765500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 156us; walltime 6.117 s; speed 25.542 us/s
# - Verilator: cpu 6.098 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %% [markdown]
# ## Register operations (cell 45)
#
# Demonstrates `set_ext_counter`, `write_dmem`, `read_dmem`, `inc_reg`. On
# hardware this needs `soc.read_mem(...)` and `soc.get_tproc_counter(...)`
# post-run, which the emulator TB doesn't expose — so we print the text ASM
# and run the program through the TB, but skip the read-back lines.

# %%
# Port of cell 45 — register ops, dmem read/write
from qick.asm_v2 import QickProgramV2
prog = QickProgramV2(soccfg)
prog.add_reg(name='myaddr')

prog.set_ext_counter(addr=1, val=1000)
prog.set_ext_counter(addr=2, val=1000)
prog.write_reg(dst='myaddr', src=2)

prog.write_dmem(addr=3, src=10)
prog.read_dmem(dst='s_core_w1', addr=3)

prog.write_dmem(addr='myaddr', src=17)
prog.read_dmem(dst='s_core_w2', addr='myaddr')

prog.inc_reg(dst='myaddr', src=-1)
prog.write_dmem(addr='myaddr', src=19)
prog.end()

print('text ASM:')
print(prog.asm())

##------------------------------------------------------------------------
## TODO: need to implement the DMA transactions to read/write from tProc
##------------------------------------------------------------------------

# On hardware:
#   soc.load_mem([1,2,3,4,5], 'dmem')
#   prog.run(soc)
#   print(soc.read_mem(5, 'dmem'))
#   print(soc.get_tproc_counter(1))
#   print(soc.get_tproc_counter(2))
# Emulator has no readback path for dmem / tproc counters yet.
# Out:
# text ASM:
#      NOP
#      REG_WR s12 imm #1000
#      REG_WR s13 imm #1000
#      REG_WR r0 imm #2
#      DMEM_WR [&3] imm #10
#      REG_WR s12 dmem [&3]
#      DMEM_WR [&r0] imm #17
#      REG_WR s13 dmem [&r0]
#      REG_WR r0 op -op(r0 + #-1)
#      DMEM_WR [&r0] imm #19
#      REG_WR s15 label NEXT
#      JUMP [s15]

# %% [markdown]
# ## Pulse updates, subroutines (cells 47–48)

# %%
# Port of cell 47 — virtual-Z subroutine applied mid-program
from qick.asm_v2 import AsmV2

class PulseUpdateProgram(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch  = cfg['ro_ch']
        gen_ch = cfg['gen_ch']

        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        ramp_len = 0.1
        self.add_gauss(ch=gen_ch, name='ramp',
                       sigma=ramp_len/10, length=ramp_len, even_length=True)
        self.add_pulse(ch=gen_ch, name='myflattop', ro_ch=ro_ch,
                       style='flat_top', envelope='ramp',
                       freq=cfg['freq'], length=0.05, phase=0, gain=1.0)

        sub = AsmV2()
        for wname in self.list_pulse_waveforms('myflattop'):
            sub.read_wmem(name=wname)
            sub.inc_reg(dst='w_phase', src=self.deg2reg(90, gen_ch=cfg['gen_ch']))
            sub.write_wmem(name=wname)
        self.add_subroutine('virt_z', sub)

        self.add_readoutconfig(ch=ro_ch, name='myro', freq=cfg['freq'], gen_ch=gen_ch)
        self.send_readoutconfig(ch=ro_ch, name='myro', t=0)

    def _body(self, cfg):
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'], ddr4=True)
        self.pulse(ch=cfg['gen_ch'], name='myflattop', t=0)
        self.call('virt_z')
        self.pulse(ch=cfg['gen_ch'], name='myflattop', t=0.2)
        self.pulse(ch=cfg['gen_ch'], name='myflattop', t=0.4)
        self.call('virt_z')
        self.pulse(ch=cfg['gen_ch'], name='myflattop', t=0.6)


config = {
    'gen_ch':    GEN_CH,
    'ro_ch':     RO_CH,
    'freq':      FREQ,
    'trig_time': TRIG_TIME,
    'ro_len':    0.9,
}
prog = PulseUpdateProgram(soccfg, reps=2, final_delay=0.5, cfg=config)

OUT = ARTIFACTS_ROOT / 'pulse_update'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT)

iq_list = prog.acquire_decimated(soc, rounds=10)
t = prog.get_time_axis(ro_index=0)

fig, axes = plt.subplots(len(iq_list[0]), 1, figsize=(10,6))

for ii, iq in enumerate(iq_list[0]):
    plot = axes[ii]

    plot.plot(t, iq[:,0], label="I value")
    plot.plot(t, iq[:,1], label="Q value")
    plot.plot(t, np.abs(iq.dot([1,1j])), label="magnitude")
    plot.legend()
    plot.set_title("rep %d"%(ii))
    plot.set_ylabel("a.u.")
    plot.set_xlabel("us");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 40 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 40 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12415600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12565600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12715600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12865600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13015600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13165600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13315600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13465600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13605500.000 - Start tProc execution ###
# ### 14605500.000 - End tProc execution ###
# ### 14605500.000 - Reading avg/dec buffers ###
# ### 66905500.000 - Closing CSV files ###
# *** 66905500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.621 s; speed 25.638 us/s
# - Verilator: cpu 2.610 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 32 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 32 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12405600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12555600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12705600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12855600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13005600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13155600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13305600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13455600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13595500.000 - Start tProc execution ###
# ### 14595500.000 - End tProc execution ###
# ### 14595500.000 - Reading avg/dec buffers ###
# ### 66895500.000 - Closing CSV files ###
# *** 66895500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.650 s; speed 25.295 us/s
# - Verilator: cpu 2.645 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 7 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 7 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12375600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12525600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12675600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12825600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 12975600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13125600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13275600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13425600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13565500.000 - Start tProc execution ###
# ### 14565500.000 - End tProc execution ###
# ### 14565500.000 - Reading avg/dec buffers ###
# ### 66865500.000 - Closing CSV files ###
# *** 66865500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.601 s; speed 25.751 us/s
# - Verilator: cpu 2.597 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 25 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 25 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12395600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12545600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12695600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12845600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 12995600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13145600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13295600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13445600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13585500.000 - Start tProc execution ###
# ### 14585500.000 - End tProc execution ###
# ### 14585500.000 - Reading avg/dec buffers ###
# ### 66885500.000 - Closing CSV files ###
# *** 66885500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.607 s; speed 25.707 us/s
# - Verilator: cpu 2.602 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 65 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 65 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12435600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12585600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12735600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12885600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13035600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13185600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13335600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13485600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13625500.000 - Start tProc execution ###
# ### 14625500.000 - End tProc execution ###
# ### 14625500.000 - Reading avg/dec buffers ###
# ### 66925500.000 - Closing CSV files ###
# *** 66925500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.696 s; speed 24.897 us/s
# - Verilator: cpu 2.688 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 86 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 86 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12455600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12605600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12755600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12905600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13055600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13205600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13355600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13505600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13645500.000 - Start tProc execution ###
# ### 14645500.000 - End tProc execution ###
# ### 14645500.000 - Reading avg/dec buffers ###
# ### 66945500.000 - Closing CSV files ###
# *** 66945500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.653 s; speed 25.324 us/s
# - Verilator: cpu 2.644 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.037 s (elab=0.000, cvt=0.000, bld=0.034); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 71 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 71 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12445600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12595600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12745600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12895600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13045600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13195600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13345600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13495600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13635500.000 - Start tProc execution ###
# ### 14635500.000 - End tProc execution ###
# ### 14635500.000 - Reading avg/dec buffers ###
# ### 66935500.000 - Closing CSV files ###
# *** 66935500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.630 s; speed 25.505 us/s
# - Verilator: cpu 2.624 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 51 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 51 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12425600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12575600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12725600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12875600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13025600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13175600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13325600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13475600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13615500.000 - Start tProc execution ###
# ### 14615500.000 - End tProc execution ###
# ### 14615500.000 - Reading avg/dec buffers ###
# ### 66915500.000 - Closing CSV files ###
# *** 66915500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.646 s; speed 25.343 us/s
# - Verilator: cpu 2.640 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 77 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 77 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12445600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12595600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12745600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12895600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13045600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13195600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13345600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13495600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13635500.000 - Start tProc execution ###
# ### 14635500.000 - End tProc execution ###
# ### 14635500.000 - Reading avg/dec buffers ###
# ### 66935500.000 - Closing CSV files ###
# *** 66935500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.608 s; speed 25.711 us/s
# - Verilator: cpu 2.603 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.034 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 62 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 62 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12435600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12585600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12735600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12885600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13035600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13185600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13335600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13485600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13625500.000 - Start tProc execution ###
# ### 14625500.000 - End tProc execution ###
# ### 14625500.000 - Reading avg/dec buffers ###
# ### 66925500.000 - Closing CSV files ###
# *** 66925500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.650 s; speed 25.302 us/s
# - Verilator: cpu 2.645 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %%
# Port of cell 48 — like 47 but resets w_phase back to 0 at end of body
from qick.asm_v2 import AsmV2

class PulseUpdateProgram2(AveragerProgramV2):
    def _initialize(self, cfg):
        ro_ch  = cfg['ro_ch']
        gen_ch = cfg['gen_ch']

        self.declare_gen(ch=gen_ch, nqz=1)
        self.declare_readout(ch=ro_ch, length=cfg['ro_len'])

        ramp_len = 0.1
        self.add_gauss(ch=gen_ch, name='ramp',
                       sigma=ramp_len/10, length=ramp_len, even_length=True)
        self.add_pulse(ch=gen_ch, name='myflattop', ro_ch=ro_ch,
                       style='flat_top', envelope='ramp',
                       freq=cfg['freq'], length=0.05, phase=0, gain=1.0)

        sub = AsmV2()
        for wname in self.list_pulse_waveforms('myflattop'):
            sub.read_wmem(name=wname)
            sub.inc_reg(dst='w_phase', src=self.deg2reg(90, gen_ch=cfg['gen_ch']))
            sub.write_wmem(name=wname)
        self.add_subroutine('virt_z', sub)

        self.add_readoutconfig(ch=ro_ch, name='myro', freq=cfg['freq'], gen_ch=gen_ch)
        self.send_readoutconfig(ch=ro_ch, name='myro', t=0)

    def _body(self, cfg):
        self.trigger(ros=[cfg['ro_ch']], pins=[0], t=cfg['trig_time'], ddr4=True)
        self.pulse(ch=cfg['gen_ch'], name='myflattop', t=0)
        self.call('virt_z')
        self.pulse(ch=cfg['gen_ch'], name='myflattop', t=0.2)
        self.pulse(ch=cfg['gen_ch'], name='myflattop', t=0.4)
        self.call('virt_z')
        self.pulse(ch=cfg['gen_ch'], name='myflattop', t=0.6)

        # reset the phase to 0
        for wname in self.list_pulse_waveforms('myflattop'):
            self.read_wmem(name=wname)
            self.write_reg(dst='w_phase', src=0)
            self.write_wmem(name=wname)


config = {
    'gen_ch':    GEN_CH,
    'ro_ch':     RO_CH,
    'freq':      FREQ,
    'trig_time': TRIG_TIME,
    'ro_len':    0.9,
}
prog = PulseUpdateProgram2(soccfg, reps=2, final_delay=0.5, cfg=config)

OUT = ARTIFACTS_ROOT / 'pulse_update2'
OUT.mkdir(parents=True, exist_ok=True)
soc = soc.make_soc(memdir=OUT)

iq_list = prog.acquire_decimated(soc, rounds=10)
t = prog.get_time_axis(ro_index=0)

fig, axes = plt.subplots(len(iq_list[0]), 1, figsize=(10,6))

for ii, iq in enumerate(iq_list[0]):
    plot = axes[ii]

    plot.plot(t, iq[:,0], label="I value")
    plot.plot(t, iq[:,1], label="Q value")
    plot.plot(t, np.abs(iq.dot([1,1j])), label="magnitude")
    plot.legend()
    plot.set_title("rep %d"%(ii))
    plot.set_ylabel("a.u.")
    plot.set_xlabel("us");
# Out:
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 63 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 63 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12435600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12585600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12735600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12885600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13035600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13185600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13335600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13485600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13625500.000 - Start tProc execution ###
# ### 14625500.000 - End tProc execution ###
# ### 14625500.000 - Reading avg/dec buffers ###
# ### 66925500.000 - Closing CSV files ###
# *** 66925500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.636 s; speed 25.434 us/s
# - Verilator: cpu 2.631 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 74 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 74 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12445600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12595600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12745600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12895600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13045600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13195600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13345600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13495600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13635500.000 - Start tProc execution ###
# ### 14635500.000 - End tProc execution ###
# ### 14635500.000 - Reading avg/dec buffers ###
# ### 66935500.000 - Closing CSV files ###
# *** 66935500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.656 s; speed 25.253 us/s
# - Verilator: cpu 2.651 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 4 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 4 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12375600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12525600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12675600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12825600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 12975600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13125600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13275600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13425600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13565500.000 - Start tProc execution ###
# ### 14565500.000 - End tProc execution ###
# ### 14565500.000 - Reading avg/dec buffers ###
# ### 66865500.000 - Closing CSV files ###
# *** 66865500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.619 s; speed 25.570 us/s
# - Verilator: cpu 2.615 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 58 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 58 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12425600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12575600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12725600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12875600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13025600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13175600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13325600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13475600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13615500.000 - Start tProc execution ###
# ### 14615500.000 - End tProc execution ###
# ### 14615500.000 - Reading avg/dec buffers ###
# ### 66915500.000 - Closing CSV files ###
# *** 66915500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.645 s; speed 25.342 us/s
# - Verilator: cpu 2.641 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.035 s (elab=0.000, cvt=0.000, bld=0.033); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 94 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 94 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12465600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12615600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12765600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12915600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13065600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13215600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13365600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13515600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13655500.000 - Start tProc execution ###
# ### 14655500.000 - End tProc execution ###
# ### 14655500.000 - Reading avg/dec buffers ###
# ### 66955500.000 - Closing CSV files ###
# *** 66955500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.626 s; speed 25.550 us/s
# - Verilator: cpu 2.621 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.035 s (elab=0.000, cvt=0.000, bld=0.033); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 63 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 63 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12435600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12585600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12735600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12885600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13035600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13185600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13335600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13485600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13625500.000 - Start tProc execution ###
# ### 14625500.000 - End tProc execution ###
# ### 14625500.000 - Reading avg/dec buffers ###
# ### 66925500.000 - Closing CSV files ###
# *** 66925500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.658 s; speed 25.249 us/s
# - Verilator: cpu 2.651 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.034 s (elab=0.000, cvt=0.000, bld=0.032); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 81 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 81 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12455600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12605600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12755600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12905600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13055600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13205600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13355600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13505600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13645500.000 - Start tProc execution ###
# ### 14645500.000 - End tProc execution ###
# ### 14645500.000 - Reading avg/dec buffers ###
# ### 66945500.000 - Closing CSV files ###
# *** 66945500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.607 s; speed 25.733 us/s
# - Verilator: cpu 2.602 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.039 s (elab=0.000, cvt=0.000, bld=0.037); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 79 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 79 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12445600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12595600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12745600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12895600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13045600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13195600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13345600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13495600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13635500.000 - Start tProc execution ###
# ### 14635500.000 - End tProc execution ###
# ### 14635500.000 - Reading avg/dec buffers ###
# ### 66935500.000 - Closing CSV files ###
# *** 66935500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.626 s; speed 25.541 us/s
# - Verilator: cpu 2.621 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 67 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 67 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12435600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12585600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12735600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12885600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13035600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13185600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13335600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13485600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13625500.000 - Start tProc execution ###
# ### 14625500.000 - End tProc execution ###
# ### 14625500.000 - Reading avg/dec buffers ###
# ### 66925500.000 - Closing CSV files ###
# *** 66925500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.631 s; speed 25.480 us/s
# - Verilator: cpu 2.627 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv
# [ok] Wrote /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/axi_replay.txt  (8 transactions)
#
# --- tb_qick_emu.sv address routing parameters ---
# # Paste these localparam values into tb_qick_emu.sv if defaults differ:
# localparam integer TPROC_BASE  = 40'h400260000;
# localparam integer SG_BASE_LO  = 40'h4001C0000;  // 2 gen IP(s)
# localparam integer SG_BASE_HI  = 40'h4001E0000;
# localparam integer AVG_BASE_LO = 40'h400060000;  // 1 avgbuf IP(s)
# localparam integer AVG_BASE_HI = 40'h400070000;
# -------------------------------------------------
#
# [verilate] Building QICKEmu_harness ...
# - Verilator: Built from 0.000 MB sources in 0 modules, into 0.000 MB in 0 C++ files needing 0.000 MB
# - Verilator: Walltime 0.033 s (elab=0.000, cvt=0.000, bld=0.031); cpu 0.002 s on 28 threads; alloced 18.254 MB
# [sim] Running simulation with EMU_DIR=/home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ...
# ### EMU_DIR set to /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 via plusarg ###
# ### PRE_RUN_DELAY_NS overridden to 36 ns ###
# ### RO_AVG_LEN overridden to 2 via plusarg ###
# ### RO_DEC_LEN overridden to 552 via plusarg ###
# ### MR_LEN overridden to 0 via plusarg ###
# Loading FIR coefficients...
# ### Opening CSV: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/dac_out.csv ###
# *** Start Test ***
# ### Loading tproc memories from: /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2 ###
# ### VERIFY P_MEM[1] = 8c600000000000000c ###
# ### tproc memories loaded ###
# ###          1265600.000 - Task sg_load_mem() channel 0 start ###
# ### 1265600.000 - Loading SG ch0 envelope from /home/dmartin2/hrl-labs-clinic/qick_fork_mmdiego_qickemu/emulator/artifacts/00_intro/pulse_update2/sgmem_ch0.mem ###
# ### 11365500.000 - SG ch0 envelope loaded ###
# ###         11365500.000 - Task sg_load_mem() end ###
# ### 12365500.000 - Applying pre-run startup delay of 36 ns ###
# ### replay line #0 parsed: addr=0x001c0010 data=0x00000001 ###
# ### 12405600.000 - Routing AXI write: addr=0x001c0010 data=0x00000001 ###
# ### replay line #1 parsed: addr=0x00060000 data=0x00000000 ###
# ### 12555600.000 - Routing AXI write: addr=0x00060000 data=0x00000000 ###
# ### replay line #2 parsed: addr=0x00060008 data=0x00000114 ###
# ### 12705600.000 - Routing AXI write: addr=0x00060008 data=0x00000114 ###
# ### replay line #3 parsed: addr=0x00060018 data=0x00000000 ###
# ### 12855600.000 - Routing AXI write: addr=0x00060018 data=0x00000000 ###
# ### replay line #4 parsed: addr=0x00060020 data=0x00000114 ###
# ### 13005600.000 - Routing AXI write: addr=0x00060020 data=0x00000114 ###
# ### replay line #5 parsed: addr=0x00060000 data=0x00000001 ###
# ### 13155600.000 - Routing AXI write: addr=0x00060000 data=0x00000001 ###
# ### replay line #6 parsed: addr=0x00060018 data=0x00000001 ###
# ### 13305600.000 - Routing AXI write: addr=0x00060018 data=0x00000001 ###
# ### replay line #7 parsed: addr=0x00260000 data=0x00000004 ###
# ### 13455600.000 - Routing AXI write: addr=0x00260000 data=0x00000004 ###
# ### AXI replay done: 8 transactions replayed ###
# ### 13595500.000 - Start tProc execution ###
# ### 14595500.000 - End tProc execution ###
# ### 14595500.000 - Reading avg/dec buffers ###
# ### 66895500.000 - Closing CSV files ###
# *** 66895500.000 - End Simulation ***
# - ../../emulator/testbench/QICKEmu_harness.sv:1205: Verilog $finish
# - S i m u l a t i o n   R e p o r t: Verilator 5.043 devel
# - Verilator: $finish at 67us; walltime 2.612 s; speed 25.658 us/s
# - Verilator: cpu 2.607 s on 1 threads; alloced 225 MB
# [ok] CSV outputs: dac=dac_out.csv, avg=avg_out.csv, dec=dec_out.csv, mr=mr_out.csv

# %% [markdown]
# ## Understanding ASM and program structure (cells 51–57)
#
# Pure pedagogy — no simulation.

# %%
# Port of cell 51 — print the last program we ran
print(prog)
# Out:
# macros:
# 	WriteReg(dst='s_core_w1', src=0)
# 	ConfigReadout(ch=0, name='myro', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fec40>}, t_regs={'t': 0})
# 	Delay(t=1.0, auto=True, gens=True, ros=True, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fecd0>}, t_regs={'t': 430})
# 	OpenLoop(n=2, name='reps')
# 	Trigger(ros=[0], tts=[], pins=[0], t=0.4, width=0.023251488095238096, ddr4=True, mr=False, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fee50>, 'width': <qick.asm_v2.QickParam object at 0x7f44259feca0>}, t_regs={'t': 172, 'width': 10}, outdict=defaultdict(<class 'int'>, {}), trigset={0, 9, 10})
# 	Pulse(ch=0, name='myflattop', t=0, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fed90>}, t_regs={'t': 0})
# 	Call(label='virt_z')
# 	Pulse(ch=0, name='myflattop', t=0.2, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fef70>}, t_regs={'t': 86})
# 	Pulse(ch=0, name='myflattop', t=0.4, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fefd0>}, t_regs={'t': 172})
# 	Call(label='virt_z')
# 	Pulse(ch=0, name='myflattop', t=0.6, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fef40>}, t_regs={'t': 258})
# 	ReadWmem(name='myflattop_w0')
# 	WriteReg(dst='w_phase', src=0)
# 	WriteWmem(name='myflattop_w0')
# 	ReadWmem(name='myflattop_w1')
# 	WriteReg(dst='w_phase', src=0)
# 	WriteWmem(name='myflattop_w1')
# 	ReadWmem(name='myflattop_w2')
# 	WriteReg(dst='w_phase', src=0)
# 	WriteWmem(name='myflattop_w2')
# 	Wait(t=0, auto=True, gens=False, ros=True, tag=None, no_warn=True, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fe970>}, t_regs={'t': 558})
# 	Delay(t=0.5, auto=True, gens=True, ros=True, tag=None, t_params={'t': <qick.asm_v2.QickParam object at 0x7f44259fe8b0>}, t_regs={'t': 773})
# 	IncReg(dst='s_core_w1', src=1)
# 	CloseLoop()
# 	End()
# 	Label(label='virt_z')
# 	ReadWmem(name='myflattop_w0')
# 	IncReg(dst='w_phase', src=1073741824)
# 	WriteWmem(name='myflattop_w0')
# 	ReadWmem(name='myflattop_w1')
# 	IncReg(dst='w_phase', src=1073741824)
# 	WriteWmem(name='myflattop_w1')
# 	ReadWmem(name='myflattop_w2')
# 	IncReg(dst='w_phase', src=1073741824)
# 	WriteWmem(name='myflattop_w2')
# 	AsmInst(inst={'CMD': 'RET'}, addr_inc=1)
# registers:
# 	reps: QickRegisterV2(addr=0, init=None)
# 	scratch: QickRegisterV2(addr=1, init=None)
# pulses:
# 	myflattop: QickPulse(waveforms=[Waveform(name='myflattop_w0', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=2, steps={}), length=30, conf=8), Waveform(name='myflattop_w1', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=0, gain=QickRawParam(par='gain', start=16383, spans={}, quantize=1, steps={}), length=QickRawParam(par='length', start=30, spans={}, quantize=1, steps={}), conf=9), Waveform(name='myflattop_w2', freq=QickRawParam(par='freq', start=44810940, spans={}, quantize=10, steps={}), phase=QickRawParam(par='phase', start=0, spans={}, quantize=1, steps={}), env=30, gain=QickRawParam(par='gain', start=32766, spans={}, quantize=2, steps={}), length=30, conf=8)])
# 	myro: QickPulse(waveforms=[Waveform(name='myro_w0', freq=QickRawParam(par='freq', start=-174762666, spans={}, quantize=-39, steps={}), phase=0, env=0, gain=0, length=3, conf=264)])
# expanded ASM:
# 	     NOP
# 	     REG_WR s12 imm #0
# 	     WPORT_WR p4 wmem [&3] @0
# 	     TIME #430 inc_ref
# 	     REG_WR r0 imm #0
# 	reps:
# 	     TRIG p0 set @172
# 	     TRIG p9 set @172
# 	     TRIG p10 set @172
# 	     TRIG p0 clr @182
# 	     TRIG p9 clr @182
# 	     TRIG p10 clr @182
# 	     WPORT_WR p0 wmem [&0] @0
# 	     WPORT_WR p0 wmem [&1] @0
# 	     WPORT_WR p0 wmem [&2] @0
# 	     REG_WR s15 label virt_z
# 	     CALL [s15]
# 	     WPORT_WR p0 wmem [&0] @86
# 	     WPORT_WR p0 wmem [&1] @86
# 	     WPORT_WR p0 wmem [&2] @86
# 	     WPORT_WR p0 wmem [&0] @172
# 	     WPORT_WR p0 wmem [&1] @172
# 	     WPORT_WR p0 wmem [&2] @172
# 	     REG_WR s15 label virt_z
# 	     CALL [s15]
# 	     WPORT_WR p0 wmem [&0] @258
# 	     WPORT_WR p0 wmem [&1] @258
# 	     WPORT_WR p0 wmem [&2] @258
# 	     REG_WR r_wave wmem [&0]
# 	     REG_WR w1 imm #0
# 	     WMEM_WR &0
# 	     REG_WR r_wave wmem [&1]
# 	     REG_WR w1 imm #0
# 	     WMEM_WR &1
# 	     REG_WR r_wave wmem [&2]
# 	     REG_WR w1 imm #0
# 	     WMEM_WR &2
# 	     REG_WR s15 label SKIP
# 	     WAIT [s15] @558 time
# 	     TIME #773 inc_ref
# 	     REG_WR s12 op -op(s12 + #1)
# 	     REG_WR s15 label reps
# 	     TEST -op(r0 - #1)
# 	     JUMP [s15] -if(NZ) -wr(r0 op) -op(r0 + #1)
# 	     REG_WR s15 label NEXT
# 	     JUMP [s15]
# 	virt_z:
# 	     REG_WR r_wave wmem [&0]
# 	     REG_WR r1 imm #1073741824
# 	     REG_WR w1 op -op(w1 + r1)
# 	     WMEM_WR &0
# 	     REG_WR r_wave wmem [&1]
# 	     REG_WR r1 imm #1073741824
# 	     REG_WR w1 op -op(w1 + r1)
# 	     WMEM_WR &1
# 	     REG_WR r_wave wmem [&2]
# 	     REG_WR r1 imm #1073741824
# 	     REG_WR w1 op -op(w1 + r1)
# 	     WMEM_WR &2
# 	RET

# %%
# Port of cell 52
prog.prog_list
# Out:
# [{'CMD': 'NOP', 'P_ADDR': 0},
#  {'CMD': 'REG_WR',
#   'DST': 's12',
#   'SRC': 'imm',
#   'LIT': '#0',
#   'P_ADDR': 1,
#   'LINE': 1},
#  {'CMD': 'WPORT_WR',
#   'DST': '4',
#   'SRC': 'wmem',
#   'ADDR': '&3',
#   'TIME': '@0',
#   'P_ADDR': 2,
#   'LINE': 2},
#  {'CMD': 'TIME', 'C_OP': 'inc_ref', 'LIT': '#430', 'P_ADDR': 3, 'LINE': 3},
#  {'CMD': 'REG_WR',
#   'DST': 'r0',
#   'SRC': 'imm',
#   'LIT': '#0',
#   'P_ADDR': 4,
#   'LINE': 4},
#  {'CMD': 'TRIG',
#   'SRC': 'set',
#   'DST': '0',
#   'TIME': '@172',
#   'P_ADDR': 5,
#   'LINE': 6},
#  {'CMD': 'TRIG',
#   'SRC': 'set',
#   'DST': '9',
#   'TIME': '@172',
#   'P_ADDR': 6,
#   'LINE': 7},
#  {'CMD': 'TRIG',
#   'SRC': 'set',
#   'DST': '10',
#   'TIME': '@172',
#   'P_ADDR': 7,
#   'LINE': 8},
#  {'CMD': 'TRIG',
#   'SRC': 'clr',
#   'DST': '0',
#   'TIME': '@182',
#   'P_ADDR': 8,
#   'LINE': 9},
#  {'CMD': 'TRIG',
#   'SRC': 'clr',
#   'DST': '9',
#   'TIME': '@182',
#   'P_ADDR': 9,
#   'LINE': 10},
#  {'CMD': 'TRIG',
#   'SRC': 'clr',
#   'DST': '10',
#   'TIME': '@182',
#   'P_ADDR': 10,
#   'LINE': 11},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&0',
#   'TIME': '@0',
#   'P_ADDR': 11,
#   'LINE': 12},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&1',
#   'TIME': '@0',
#   'P_ADDR': 12,
#   'LINE': 13},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&2',
#   'TIME': '@0',
#   'P_ADDR': 13,
#   'LINE': 14},
#  {'CMD': 'REG_WR',
#   'DST': 's15',
#   'SRC': 'label',
#   'LABEL': 'virt_z',
#   'P_ADDR': 14,
#   'LINE': 15},
#  {'CMD': 'CALL', 'ADDR': 's15', 'P_ADDR': 15, 'LINE': 16},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&0',
#   'TIME': '@86',
#   'P_ADDR': 16,
#   'LINE': 17},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&1',
#   'TIME': '@86',
#   'P_ADDR': 17,
#   'LINE': 18},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&2',
#   'TIME': '@86',
#   'P_ADDR': 18,
#   'LINE': 19},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&0',
#   'TIME': '@172',
#   'P_ADDR': 19,
#   'LINE': 20},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&1',
#   'TIME': '@172',
#   'P_ADDR': 20,
#   'LINE': 21},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&2',
#   'TIME': '@172',
#   'P_ADDR': 21,
#   'LINE': 22},
#  {'CMD': 'REG_WR',
#   'DST': 's15',
#   'SRC': 'label',
#   'LABEL': 'virt_z',
#   'P_ADDR': 22,
#   'LINE': 23},
#  {'CMD': 'CALL', 'ADDR': 's15', 'P_ADDR': 23, 'LINE': 24},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&0',
#   'TIME': '@258',
#   'P_ADDR': 24,
#   'LINE': 25},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&1',
#   'TIME': '@258',
#   'P_ADDR': 25,
#   'LINE': 26},
#  {'CMD': 'WPORT_WR',
#   'DST': '0',
#   'SRC': 'wmem',
#   'ADDR': '&2',
#   'TIME': '@258',
#   'P_ADDR': 26,
#   'LINE': 27},
#  {'CMD': 'REG_WR',
#   'DST': 'r_wave',
#   'SRC': 'wmem',
#   'ADDR': '&0',
#   'P_ADDR': 27,
#   'LINE': 28},
#  {'CMD': 'REG_WR',
#   'DST': 'w1',
#   'SRC': 'imm',
#   'LIT': '#0',
#   'P_ADDR': 28,
#   'LINE': 29},
#  {'CMD': 'WMEM_WR', 'DST': '&0', 'P_ADDR': 29, 'LINE': 30},
#  {'CMD': 'REG_WR',
#   'DST': 'r_wave',
#   'SRC': 'wmem',
#   'ADDR': '&1',
#   'P_ADDR': 30,
#   'LINE': 31},
#  {'CMD': 'REG_WR',
#   'DST': 'w1',
#   'SRC': 'imm',
#   'LIT': '#0',
#   'P_ADDR': 31,
#   'LINE': 32},
#  {'CMD': 'WMEM_WR', 'DST': '&1', 'P_ADDR': 32, 'LINE': 33},
#  {'CMD': 'REG_WR',
#   'DST': 'r_wave',
#   'SRC': 'wmem',
#   'ADDR': '&2',
#   'P_ADDR': 33,
#   'LINE': 34},
#  {'CMD': 'REG_WR',
#   'DST': 'w1',
#   'SRC': 'imm',
#   'LIT': '#0',
#   'P_ADDR': 34,
#   'LINE': 35},
#  {'CMD': 'WMEM_WR', 'DST': '&2', 'P_ADDR': 35, 'LINE': 36},
#  {'CMD': 'REG_WR',
#   'DST': 's15',
#   'SRC': 'label',
#   'LABEL': 'SKIP',
#   'P_ADDR': 36,
#   'LINE': 37},
#  {'CMD': 'WAIT',
#   'ADDR': 's15',
#   'C_OP': 'time',
#   'TIME': '@558',
#   'P_ADDR': 37,
#   'LINE': 38},
#  {'CMD': 'TIME', 'C_OP': 'inc_ref', 'LIT': '#773', 'P_ADDR': 39, 'LINE': 39},
#  {'CMD': 'REG_WR',
#   'DST': 's12',
#   'SRC': 'op',
#   'OP': 's12 + #1',
#   'P_ADDR': 40,
#   'LINE': 40},
#  {'CMD': 'REG_WR',
#   'DST': 's15',
#   'SRC': 'label',
#   'LABEL': 'reps',
#   'P_ADDR': 41,
#   'LINE': 41},
#  {'CMD': 'TEST', 'OP': 'r0 - #1', 'P_ADDR': 42, 'LINE': 42},
#  {'CMD': 'JUMP',
#   'ADDR': 's15',
#   'IF': 'NZ',
#   'WR': 'r0 op',
#   'OP': 'r0 + #1',
#   'P_ADDR': 43,
#   'LINE': 43},
#  {'CMD': 'REG_WR',
#   'DST': 's15',
#   'SRC': 'label',
#   'LABEL': 'NEXT',
#   'P_ADDR': 44,
#   'LINE': 44},
#  {'CMD': 'JUMP', 'ADDR': 's15', 'P_ADDR': 45, 'LINE': 45},
#  {'CMD': 'REG_WR',
#   'DST': 'r_wave',
#   'SRC': 'wmem',
#   'ADDR': '&0',
#   'P_ADDR': 46,
#   'LINE': 47},
#  {'CMD': 'REG_WR',
#   'DST': 'r1',
#   'SRC': 'imm',
#   'LIT': '#1073741824',
#   'P_ADDR': 47,
#   'LINE': 48},
#  {'CMD': 'REG_WR',
#   'DST': 'w1',
#   'SRC': 'op',
#   'OP': 'w1 + r1',
#   'P_ADDR': 48,
#   'LINE': 49},
#  {'CMD': 'WMEM_WR', 'DST': '&0', 'P_ADDR': 49, 'LINE': 50},
#  {'CMD': 'REG_WR',
#   'DST': 'r_wave',
#   'SRC': 'wmem',
#   'ADDR': '&1',
#   'P_ADDR': 50,
#   'LINE': 51},
#  {'CMD': 'REG_WR',
#   'DST': 'r1',
#   'SRC': 'imm',
#   'LIT': '#1073741824',
#   'P_ADDR': 51,
#   'LINE': 52},
#  {'CMD': 'REG_WR',
#   'DST': 'w1',
#   'SRC': 'op',
#   'OP': 'w1 + r1',
#   'P_ADDR': 52,
#   'LINE': 53},
#  {'CMD': 'WMEM_WR', 'DST': '&1', 'P_ADDR': 53, 'LINE': 54},
#  {'CMD': 'REG_WR',
#   'DST': 'r_wave',
#   'SRC': 'wmem',
#   'ADDR': '&2',
#   'P_ADDR': 54,
#   'LINE': 55},
#  {'CMD': 'REG_WR',
#   'DST': 'r1',
#   'SRC': 'imm',
#   'LIT': '#1073741824',
#   'P_ADDR': 55,
#   'LINE': 56},
#  {'CMD': 'REG_WR',
#   'DST': 'w1',
#   'SRC': 'op',
#   'OP': 'w1 + r1',
#   'P_ADDR': 56,
#   'LINE': 57},
#  {'CMD': 'WMEM_WR', 'DST': '&2', 'P_ADDR': 57, 'LINE': 58},
#  {'CMD': 'RET', 'P_ADDR': 58, 'LINE': 59}]

# %%
# Port of cell 54 — text ASM ↔ machine code ↔ ASM dicts round-trip
from qick.tprocv2_assembler import Assembler

pstr = 'TIME #384 inc_ref\nREG_WR r_wave wmem [&0]\nWMEM_WR [&0]\n.END'
print('text ASM:')
print(pstr)

print('\nmachine code:')
for a in Assembler.str_asm2bin(pstr)[1]:
    print([hex(b) for b in a])

print('\nASM dicts:')
plist, labels = Assembler.str_asm2list(pstr)
for a in plist:
    print(a)
for a in labels.items():
    print(a)

print('\ntext ASM → ASM dicts → text ASM:')
print(Assembler.list2asm(plist, labels))
# Out:
# text ASM:
# TIME #384 inc_ref
# REG_WR r_wave wmem [&0]
# WMEM_WR [&0]
# .END
#
# machine code:
# ['0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0xc000', '0x8000000', '0x4c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x40000000', '0x9c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x40000000', '0xbe', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x8000', '0x3c', '0x0', '0x0', '0x0', '0x0', '0x0']
#
# ASM dicts:
# {'P_ADDR': 0, 'CMD': 'NOP'}
# {'P_ADDR': 1, 'LINE': 1, 'LIT': '#384', 'CMD': 'TIME', 'C_OP': 'inc_ref'}
# {'P_ADDR': 2, 'LINE': 2, 'ADDR': '&0', 'CMD': 'REG_WR', 'DST': 'r_wave', 'SRC': 'wmem'}
# {'P_ADDR': 3, 'LINE': 3, 'CMD': 'WMEM_WR', 'DST': '[&0]'}
# {'LINE': 4, 'P_ADDR': 4, 'ADDR': '&4', 'CMD': 'JUMP'}
#
# text ASM → ASM dicts → text ASM:
#      NOP
#      TIME #384 inc_ref
#      REG_WR r_wave wmem [&0]
#      WMEM_WR [&0]
#      JUMP HERE

# %%
# Port of cell 55 — same program using asm_inst
from qick.asm_v2 import QickProgramV2
prog = QickProgramV2(soccfg)
prog.asm_inst({'CMD': 'TIME',    'C_OP': 'inc_ref', 'LIT': '#384'})
prog.asm_inst({'CMD': 'REG_WR',  'DST': 'r_wave',   'SRC': 'wmem', 'ADDR': '&0'})
prog.asm_inst({'CMD': 'WMEM_WR', 'DST': '[&0]'})
prog.end()
print('text ASM:')
print(prog.asm())

print('machine code:')
prog.compile()
for a in prog.binprog['pmem']:
    print([hex(b) for b in a])
# Out:
# text ASM:
#      NOP
#      TIME #384 inc_ref
#      REG_WR r_wave wmem [&0]
#      WMEM_WR [&0]
#      REG_WR s15 label NEXT
#      JUMP [s15]
#
# machine code:
# ['0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0xc000', '0x8000000', '0x4c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x40000000', '0x9c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x40000000', '0xbe', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x28f', '0x60000000', '0x8c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x0', '0x2c', '0x0', '0x0', '0x0', '0x0', '0x0']

# %%
# Port of cell 56 — same program using macro objects
from qick.asm_v2 import QickProgramV2, Waveform, ReadWmem, WriteWmem, Delay

prog = QickProgramV2(soccfg)
prog.add_raw_pulse('mypulse', [Waveform(0, 0, 0, 0, 0, 0)])
prog.append_macro(Delay(t=1.0, auto=False))
for wname in prog.list_pulse_waveforms('mypulse'):
    prog.append_macro(ReadWmem(name=wname))
    prog.append_macro(WriteWmem(name=wname))
prog.end()

print('text ASM:')
print(prog.asm())
print('machine code:')
prog.compile()
for a in prog.binprog['pmem']:
    print([hex(b) for b in a])
# Out:
# text ASM:
#      NOP
#      TIME #430 inc_ref
#      REG_WR r_wave wmem [&0]
#      WMEM_WR &0
#      REG_WR s15 label NEXT
#      JUMP [s15]
#
# machine code:
# ['0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0xd700', '0x8000000', '0x4c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x40000000', '0x9c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x40000000', '0xbe', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x28f', '0x60000000', '0x8c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x0', '0x2c', '0x0', '0x0', '0x0', '0x0', '0x0']

# %%
# Port of cell 57 — same program using macro methods (most common style)
from qick.asm_v2 import QickProgramV2, Waveform

prog = QickProgramV2(soccfg)
prog.add_raw_pulse('mypulse', [Waveform(0, 0, 0, 0, 0, 0)])
prog.delay(1.0)
for wname in prog.list_pulse_waveforms('mypulse'):
    prog.read_wmem(name=wname)
    prog.write_wmem(name=wname)
prog.end()

print('text ASM:')
print(prog.asm())
print('machine code:')
prog.compile()
for a in prog.binprog['pmem']:
    print([hex(b) for b in a])
# Out:
# text ASM:
#      NOP
#      TIME #430 inc_ref
#      REG_WR r_wave wmem [&0]
#      WMEM_WR &0
#      REG_WR s15 label NEXT
#      JUMP [s15]
#
# machine code:
# ['0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0xd700', '0x8000000', '0x4c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x40000000', '0x9c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x40000000', '0xbe', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x28f', '0x60000000', '0x8c', '0x0', '0x0', '0x0', '0x0', '0x0']
# ['0x0', '0x0', '0x2c', '0x0', '0x0', '0x0', '0x0', '0x0']
