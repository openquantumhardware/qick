# %%
from qubitdriver import qubit

from matplotlib import pyplot as plt
import numpy as np

# %%
q = qubit(cavityOutputChannel = 4)

# %%
#Set LO channel 0

q.initLO('/dev/ttyACM0')
q.setLOFreq(0,5000)
q.setLOPower(0,-10)
q.enableLO()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pyserial-3.5-py3.6.egg/serial/serialposix.py in open(self)
#     321         try:
# --> 322             self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     323         except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/ttyACM0'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-5-0d417e9baff6> in <module>()
#       1 #Set LO channel 0
#       2
# ----> 3 q.initLO('/dev/ttyACM0')
#       4 q.setLOFreq(0,5000)
#       5 q.setLOPower(0,-10)
#
# /home/xilinx/jupyter_notebooks/collin/qsystem_2/pynq/qubitdriver.py in initLO(self, port)
#     128         """
#     129
# --> 130         self.synth = SynthHD(port)
#     131         self.synth.init()
#     132
#
# /usr/local/lib/python3.6/dist-packages/windfreak-0.2.1-py3.6.egg/windfreak/synth_hd.py in __init__(self, devpath)
#     345
#     346     def __init__(self, devpath):
# --> 347         super().__init__(devpath)
#     348         self._model = None
#     349         self._model = self.model
#
# /usr/local/lib/python3.6/dist-packages/windfreak-0.2.1-py3.6.egg/windfreak/device.py in __init__(self, devpath)
#       7         self._devpath = devpath
#       8         self._dev = None
# ----> 9         self.open()
#      10
#      11     def __del__(self):
#
# /usr/local/lib/python3.6/dist-packages/windfreak-0.2.1-py3.6.egg/windfreak/device.py in open(self)
#      15         if self._dev is not None:
#      16             raise RuntimeError('Device has already been opened.')
# ---> 17         self._dev = Serial(port=self._devpath, timeout=10)
#      18
#      19     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pyserial-3.5-py3.6.egg/serial/serialutil.py in __init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     242
#     243         if port is not None:
# --> 244             self.open()
#     245
#     246     #  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#
# /usr/local/lib/python3.6/dist-packages/pyserial-3.5-py3.6.egg/serial/serialposix.py in open(self)
#     323         except OSError as msg:
#     324             self.fd = None
# --> 325             raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     326         #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     327
#
# SerialException: [Errno 2] could not open port /dev/ttyACM0: [Errno 2] No such file or directory: '/dev/ttyACM0'

# %%
q.measureTOF(gain = 32767)
# Out:
# 215.0

# %%
idec, qdec, iacc, qacc = q.sendPulses(outputChannel = 4)

amps = np.abs(idec + 1j * qdec)
plt.plot(amps)
plt.title("Gaussian Pulse Example")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.show()

# %%
freqs, amps, phases = q.singleToneSpec()

# %%
fig,ax = plt.subplots(2, sharex=True)
ax[0].plot(freqs, amps)
ax[0].set_title("Amplitude")
ax[0].set_ylabel("Amplitude")
ax[1].plot(freqs, phases)
ax[1].set_ylabel("Phase")
ax[1].set_xlabel("Frequency - MHz")
ax[1].set_title("Phase")
for axis in ax:
    axis.grid()
fig.suptitle("Single-Tone Spectroscopy")
plt.show()

# %%
freqs, amps, phases = q.twoToneSpec()

# %%
fig,ax = plt.subplots(2, sharex=True)
ax[0].plot(freqs, amps)
ax[0].set_title("Amplitude")
ax[0].set_ylabel("Amplitude")
ax[1].plot(freqs, phases)
ax[1].set_ylabel("Phase")
ax[1].set_xlabel("Frequency - MHz")
ax[1].set_title("Phase")
for axis in ax:
    axis.grid()
fig.suptitle("Two-Tone Spectroscopy")
plt.show()

# %%
idec, qdec, iacc, qacc = q.rabiOscillation()

# %%
amps = np.abs(iacc + 1j * qacc)

plt.plot(amps)
plt.title("Rabi Oscillation")
# Out:
# Text(0.5,1,'Rabi Oscillation')
